# %% [markdown]
# # **Methylation Biomarkers for Predicting Cancer**
#
# ## **Deep Learning Approaches for Cancer Classification - Clinical Data**
#
# **Author:** Meg Hutch
#
# **Date:** March 1, 2020
#
# **Objective:** Use neural networks to classify cancer type.
#
# **Note:** In this version, I will only test the ability of methylation levels to classify cancer types. I will not include phenotypic data for now. Additionally, this version has our data split 70% for training and 30% for testing. The 70% training data will undergo leave-one-out-cross-fold validation to tune hyperparameters prior to testing final performance on the 30% test set.
#
# Note: This is the new version of the script where we normalize gene counts using DEseq2 in the initial pre-processing script in R. This provided more than double the number of Principal Components that make up 90% of the variance (157). Regardless, we will begin running the deep learning classifier on the revised data.
#
# Update: This script will include the clinical data

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns

# %%
# set working directory for git hub
import os
#os.chdir('/projects/p31049/Multi_Cancer_DL/')
os.chdir('C:\\Users\\User\\Box Sync/Projects/Multi_Cancer_DL/')
os. getcwd()
# Out:
# 'C:\\Users\\User\\Box Sync\\Projects\\Multi_Cancer_DL'

# %% [markdown]
# **Import Training, Testing, and Principal component data**

# %% [markdown]
# **Full Dataset**

# %%
# Training set
mcTrain_x = pd.read_csv('02_Processed_Data/Final_Datasets/mcTrain_x_Full_70_30.csv')
mcTrain_y = pd.read_csv('02_Processed_Data/Final_Datasets/mcTrain_y_Full_70_30.csv')
# Testing set
mcTest_x = pd.read_csv('02_Processed_Data/Final_Datasets/mcTest_x_Full_70_30.csv')
mcTest_y = pd.read_csv('02_Processed_Data/Final_Datasets/mcTest_y_Full_70_30.csv')
# Principal Components that make up 90% of the variance of the training set
pca_Train = pd.read_csv('02_Processed_Data/Final_Datasets/pca_train_Full_70_30.csv')
# Principal Components projected onto the test set
pca_Test = pd.read_csv('02_Processed_Data/Final_Datasets/pca_test_Full_70_30.csv')

# %%
#mcTrain_y.head()
#pca_Train.head()

# %% [markdown]
# # **Pre-Process Data**

# %%
# rename the first column name of the PC dataframes
pca_Train.rename(columns={'Unnamed: 0':'id'}, inplace=True)
pca_Test.rename(columns={'Unnamed: 0':'id'}, inplace=True)

# %% [markdown]
# **Remove genetic data from the feature sets. This is because we are replacing them with the PCs**

# %%
mcTrain_x = mcTrain_x[['id', 'dilute_library_concentration', 'age', 'gender', 'frag_mean']]
mcTest_x = mcTest_x[['id', 'dilute_library_concentration', 'age', 'gender', 'frag_mean']]

# %%
# merge PCs with clinical/phenotypic data
mcTrain_x = pd.merge(mcTrain_x, pca_Train, how="left", on="id") 
mcTest_x = pd.merge(mcTest_x, pca_Test, how="left", on="id")

# %% [markdown]
# **Drop the library concentraion (should have already controlled for this perhaps with deseq2 normalization?); Just simply keep demographic data for these experiments!**

# %%
mcTrain_x = mcTrain_x.drop(columns=["dilute_library_concentration"])
mcTest_x = mcTest_x.drop(columns=["dilute_library_concentration"])

# %% [markdown]
# **Convert id to index**

# %%
mcTrain_x = mcTrain_x.set_index('id')
mcTrain_y = mcTrain_y.set_index('id')

mcTest_x = mcTest_x.set_index('id')
mcTest_y = mcTest_y.set_index('id')

# %% [markdown]
# **Normalize Data**
#
# From my reading, it seems that normalization, as opposed to standardization, is the more optimal approach when data is not normally distributed.
#
# Normalization will rescale our values into range of [0,1]. We need to normalize both the training and test sets

# %%
from sklearn.preprocessing import MinMaxScaler

# The normalization function to be performed will convert dataframe into array, for this reason we'll have to convert it back
# Thus, need to store columns and index
# select all columns
cols = list(mcTrain_x.columns.values)
index_train = list(mcTrain_x.index)
index_test = list(mcTest_x.index)

# Normalize data
scaler = MinMaxScaler()
mcTrain_x = scaler.fit_transform(mcTrain_x.astype(np.float))
mcTest_x = scaler.fit_transform(mcTest_x.astype(np.float))

# Convert back to dataframe
mcTrain_x = pd.DataFrame(mcTrain_x, columns = cols, index = index_train)
mcTest_x = pd.DataFrame(mcTest_x, columns = cols, index = index_test)

# %% [markdown]
# # Construct & Run Neural Network

# %%
# Import PyTorch packages
import torch
from torch import nn
#from torchvision import datasets, transforms
from torch import optim
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import TensorDataset
import torch.nn.functional as F
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
mcTrain_x.shape
# Out:
# (242, 160)

# %%
# define list for results
results_ls = []

# Where we will store correct/incorrect classifications
incorrect_ls = []
correct_ls = []

# Leave-one-out-cross-fold validation function - the for loop will iterate through the dataset, removing one sample (patient)
# at a time in order to create k training and test datasets (where k = number of total samples) always with one sample missing
for index in range (0, 242):
#for index in range (0, 212): # 212 observations when we downsample healthy patients 
    # X - features; 
    mcTrain_xy_drop = mcTrain_x.drop(mcTrain_x.index[index]) # add 'drop'suffix so we can differentiate the df with index and the array that will be created in next line
    mcTrain_xy = np.array(mcTrain_xy_drop, dtype = "float32")
    
    # y - target/outputs
    mcTrain_yz_drop = mcTrain_y.drop(mcTrain_y.index[index]) 
    mcTrain_yz = np.array(mcTrain_yz_drop, dtype = "float32")
    
    # reformat into tensors
    xb = torch.from_numpy(mcTrain_xy)
    yb = torch.from_numpy(mcTrain_yz)
    
    # squeeze - function is used when we want to remove single-dimensional entries from the shape of an array.
    yb = yb.squeeze(1) 
    
    # subset the equivalent test set
    mcTrain_test_x_drop = mcTrain_x.iloc[[index]] # add 'drop'suffix so we can differentiate the df with index and the array that will be created in next line
    mcTrain_test_x = np.array(mcTrain_test_x_drop, dtype = "float32")
            
    # y - targets/outputs
    mcTrain_test_y_drop = mcTrain_y.iloc[[index]]
    mcTrain_test_y = np.array(mcTrain_test_y_drop, dtype = "float32")
        
    # Convert arrays into tensors
    test_xb = torch.from_numpy(mcTrain_test_x)
    test_yb = torch.from_numpy(mcTrain_test_y)
    
    # Define the batchsize
    batch_size = 32

    # Combine the arrays
    trainloader = TensorDataset(xb, yb)
    
    # Training Loader
    trainloader = DataLoader(trainloader, batch_size, shuffle=True)
    
    ## Build the Model and define hyperparameters
    
    # Set parameters for grid search
    #lrs = [1e-2, 1e-3, 1e-4]
    #epochs = [100, 150, 200, 250]
    
    # summarize experiment with changed parameters
    summary = ('Hidden Layers: 50, LR: 0.001, Epochs: 600')
    
    # Define the model with hidden layers
    model = nn.Sequential(nn.Linear(160, 50),
                          nn.ReLU(),
                          nn.Linear(50, 7))
                      
    # Set Stoachastic Gradient Descent Optimizer and the learning rate
    #optimizer = optim.SGD(model.parameters(), lr=0.003)

    # Set Adam optimizer: similar to stochastic gradient descent, but uses momentum which can speed up the actual fitting process, and it also adjusts the learning rate for each of the individual parameters in the model
    optimizer = optim.Adam(model.parameters(), lr=0.10,  weight_decay=0.01) # we can also change momentum parameter

    # loss function
    criterion = nn.CrossEntropyLoss() #don't use with softmax or sigmoid- PyTorch manual indicates "This criterion combines nn.LogSoftmax() and nn.NLLLoss() in one single class."
    
    # Set epochs - number of times the entire dataset will pass through the network
    epochs = 100
    for e in range(epochs):
        # Define running loss as 0
        running_loss = 0
        
        # Run the model for each xb, yb in the trainloader. For the number of epochs specified, the 
        for xb, yb in trainloader:
            # clear gradients - otherwise they are stored
            optimizer.zero_grad()
            # Training pass
            output = model.forward(xb)
            # caluclate loss calculated from the model output compared to the labels
            loss = criterion(output, yb.long()) 
            # backpropagate the loss
            loss.backward()
            # step function to update the weights
            optimizer.step()
        
            running_loss += loss.item() # loss.item() gets the scalar value held in the loss. 
            # += function: Adds the running_loss (0) with loss.item and assigns back to running_loss
        #else:
        #    print("Epoch {}/{}, Training loss: {:.5f}".format(e+1, epochs, running_loss/len(trainloader)))

    # Apply the model to the testing dataset
    # Thus will enable us to see the predictions for each class
    ps = model(test_xb)
    #print('Network Probabilities', ps)
    
    # Obtain the top prediction
    top_p, top_class = ps.topk(1, dim=1)
    #print('top prediction', top_p)
    #print('true vals', test_yb[:10])
        
    # Drop the grad by using detach
    top_p = top_p.detach().numpy()
    top_class = top_class.detach().numpy()

    # convert to integers
    top_class = top_class.astype(np.int)
    test_yb = test_yb.numpy()
    test_yb = test_yb.astype(np.int)
    
    #print('top class', top_class[:10])
    #print('prediction:', top_class)
    #print('true:', test_yb)
                
    # compare top_class to test_yb
    if top_class == test_yb:                
        results = 1 # prediction and true value are equal
    else: 
        results = 0
    
    # Create if-else statements to identify which classes are being classified correctly/incorrectly
    if results == 0:
        incorrect = test_yb
    else: 
        incorrect = np.array([[999]], dtype=int)
        
    if results == 1:
        correct = test_yb
    else: 
        correct = np.array([[999]], dtype=int)
    #print('Results:', results)
    
    results_ls.append(results)
    incorrect_ls.append(incorrect)
    correct_ls.append(correct)
    #print(results_ls)
# Out:
# Epoch 1/100, Training loss: 3.86486
# Epoch 2/100, Training loss: 2.49316
# Epoch 3/100, Training loss: 2.12299
# Epoch 4/100, Training loss: 2.28330
# Epoch 5/100, Training loss: 2.09117
# Epoch 6/100, Training loss: 2.01158
# Epoch 7/100, Training loss: 1.94137
# Epoch 8/100, Training loss: 1.96251
# Epoch 9/100, Training loss: 2.10810
# Epoch 10/100, Training loss: 2.03596
# Epoch 11/100, Training loss: 2.14616
# Epoch 12/100, Training loss: 1.87662
# Epoch 13/100, Training loss: 2.01060
# Epoch 14/100, Training loss: 1.94999
# Epoch 15/100, Training loss: 1.87980
# Epoch 16/100, Training loss: 1.91840
# Epoch 17/100, Training loss: 1.97382
# Epoch 18/100, Training loss: 1.96876
# Epoch 19/100, Training loss: 1.89302
# Epoch 20/100, Training loss: 1.92458
# Epoch 21/100, Training loss: 1.90430
# Epoch 22/100, Training loss: 1.86475
# Epoch 23/100, Training loss: 1.89969
# Epoch 24/100, Training loss: 1.92014
# Epoch 25/100, Training loss: 1.98162
# Epoch 26/100, Training loss: 1.86732
# Epoch 27/100, Training loss: 1.89438
# Epoch 28/100, Training loss: 1.86980
# Epoch 29/100, Training loss: 1.88718
# Epoch 30/100, Training loss: 2.07543
# Epoch 31/100, Training loss: 1.90037
# Epoch 32/100, Training loss: 1.91783
# Epoch 33/100, Training loss: 1.88557
# Epoch 34/100, Training loss: 1.87701
# Epoch 35/100, Training loss: 1.87475
# Epoch 36/100, Training loss: 1.91886
# Epoch 37/100, Training loss: 1.87249
# Epoch 38/100, Training loss: 1.87749
# Epoch 39/100, Training loss: 1.89510
# Epoch 40/100, Training loss: 1.95710
# Epoch 41/100, Training loss: 1.88672
# Epoch 42/100, Training loss: 1.86660
# Epoch 43/100, Training loss: 1.87038
# Epoch 44/100, Training loss: 2.12284
# Epoch 45/100, Training loss: 1.88692
# Epoch 46/100, Training loss: 1.85619
# Epoch 47/100, Training loss: 1.92618
# Epoch 48/100, Training loss: 1.92453
# Epoch 49/100, Training loss: 1.92850
# Epoch 50/100, Training loss: 1.88993
# Epoch 51/100, Training loss: 1.87642
# Epoch 52/100, Training loss: 1.97810
# Epoch 53/100, Training loss: 1.95749
# Epoch 54/100, Training loss: 1.90136
# Epoch 55/100, Training loss: 1.85696
# Epoch 56/100, Training loss: 2.04340
# Epoch 57/100, Training loss: 2.01604
# Epoch 58/100, Training loss: 1.99488
# Epoch 59/100, Training loss: 1.87812
# Epoch 60/100, Training loss: 2.28053
# Epoch 61/100, Training loss: 2.50223
# Epoch 62/100, Training loss: 2.23993
# Epoch 63/100, Training loss: 1.92117
# Epoch 64/100, Training loss: 1.97593
# Epoch 65/100, Training loss: 2.68844
# Epoch 66/100, Training loss: 2.40714
# Epoch 67/100, Training loss: 1.92682
# Epoch 68/100, Training loss: 1.94549
# Epoch 69/100, Training loss: 1.97089
# Epoch 70/100, Training loss: 2.65422
# Epoch 71/100, Training loss: 2.37553
# Epoch 72/100, Training loss: 2.86302
# Epoch 73/100, Training loss: 1.93903
# Epoch 74/100, Training loss: 3.43322
# Epoch 75/100, Training loss: 1.91974
# Epoch 76/100, Training loss: 2.08426
# Epoch 77/100, Training loss: 2.23115
# Epoch 78/100, Training loss: 2.14464
# Epoch 79/100, Training loss: 2.05094
# Epoch 80/100, Training loss: 2.01942
# Epoch 81/100, Training loss: 1.96284
# Epoch 82/100, Training loss: 1.97792
# Epoch 83/100, Training loss: 2.05982
# Epoch 84/100, Training loss: 1.95524
# Epoch 85/100, Training loss: 1.90270
# Epoch 86/100, Training loss: 1.94408
# Epoch 87/100, Training loss: 1.92075
# Epoch 88/100, Training loss: 1.88838
# Epoch 89/100, Training loss: 1.87847
# Epoch 90/100, Training loss: 2.06848
# Epoch 91/100, Training loss: 1.91973
# Epoch 92/100, Training loss: 1.93096
# Epoch 93/100, Training loss: 1.87544
# Epoch 94/100, Training loss: 1.88576
# Epoch 95/100, Training loss: 2.32050
# Epoch 96/100, Training loss: 2.07448
# Epoch 97/100, Training loss: 1.95136
# Epoch 98/100, Training loss: 1.91148
# Epoch 99/100, Training loss: 2.04682
# Epoch 100/100, Training loss: 1.96925
# Epoch 1/100, Training loss: 5.63303
# Epoch 2/100, Training loss: 2.03309
# Epoch 3/100, Training loss: 1.94394
# Epoch 4/100, Training loss: 2.04689
# Epoch 5/100, Training loss: 1.89103
# Epoch 6/100, Training loss: 2.18666
# Epoch 7/100, Training loss: 1.97583
# Epoch 8/100, Training loss: 2.62706
# Epoch 9/100, Training loss: 2.04523
# Epoch 10/100, Training loss: 2.31207
# Epoch 11/100, Training loss: 1.98475
# Epoch 12/100, Training loss: 1.90714
# Epoch 13/100, Training loss: 2.17552
# Epoch 14/100, Training loss: 1.96731
# Epoch 15/100, Training loss: 1.91033
# Epoch 16/100, Training loss: 2.24873
# Epoch 17/100, Training loss: 1.97511
# Epoch 18/100, Training loss: 1.94900
# Epoch 19/100, Training loss: 1.93132
# Epoch 20/100, Training loss: 1.96888
# Epoch 21/100, Training loss: 1.87877
# Epoch 22/100, Training loss: 2.22217
# Epoch 23/100, Training loss: 1.94586
# Epoch 24/100, Training loss: 2.29484
# Epoch 25/100, Training loss: 1.87903
# Epoch 26/100, Training loss: 1.87886
# Epoch 27/100, Training loss: 1.95398
# Epoch 28/100, Training loss: 1.94383
# Epoch 29/100, Training loss: 1.92090
# Epoch 30/100, Training loss: 1.85865
# Epoch 31/100, Training loss: 1.95293
# Epoch 32/100, Training loss: 1.92028
# Epoch 33/100, Training loss: 1.97738
# Epoch 34/100, Training loss: 1.91585
# Epoch 35/100, Training loss: 1.85871
# Epoch 36/100, Training loss: 1.97910
# Epoch 37/100, Training loss: 1.94632
# Epoch 38/100, Training loss: 1.90404
# Epoch 39/100, Training loss: 1.85787
# Epoch 40/100, Training loss: 1.89967
# Epoch 41/100, Training loss: 2.17701
# Epoch 42/100, Training loss: 1.92632
# Epoch 43/100, Training loss: 1.88163
# Epoch 44/100, Training loss: 1.87811
# Epoch 45/100, Training loss: 1.97346
# Epoch 46/100, Training loss: 1.91598
# Epoch 47/100, Training loss: 1.88930
# Epoch 48/100, Training loss: 1.87965
# Epoch 49/100, Training loss: 1.92852
# Epoch 50/100, Training loss: 1.91133
# Epoch 51/100, Training loss: 2.00712
# Epoch 52/100, Training loss: 1.90525
# Epoch 53/100, Training loss: 1.87994
# Epoch 54/100, Training loss: 1.94221
# Epoch 55/100, Training loss: 1.89873
# Epoch 56/100, Training loss: 1.97105
# Epoch 57/100, Training loss: 1.88483
# Epoch 58/100, Training loss: 1.88102
# Epoch 59/100, Training loss: 1.88158
# Epoch 60/100, Training loss: 1.93041
# Epoch 61/100, Training loss: 1.91661
# Epoch 62/100, Training loss: 1.88384
# Epoch 63/100, Training loss: 1.91666
# Epoch 64/100, Training loss: 1.95283
# Epoch 65/100, Training loss: 1.90378
# Epoch 66/100, Training loss: 1.88228
# Epoch 67/100, Training loss: 1.87572
# Epoch 68/100, Training loss: 1.88118
# Epoch 69/100, Training loss: 1.97730
# Epoch 70/100, Training loss: 1.86995
# Epoch 71/100, Training loss: 1.96114
# Epoch 72/100, Training loss: 1.87289
# Epoch 73/100, Training loss: 1.89075
# Epoch 74/100, Training loss: 1.89243
# Epoch 75/100, Training loss: 1.93623
# Epoch 76/100, Training loss: 1.86019
# Epoch 77/100, Training loss: 1.89347
# Epoch 78/100, Training loss: 1.98183
# Epoch 79/100, Training loss: 1.91786
# Epoch 80/100, Training loss: 1.86322
# Epoch 81/100, Training loss: 2.03179
# Epoch 82/100, Training loss: 2.01340
# Epoch 83/100, Training loss: 2.45024
# Epoch 84/100, Training loss: 1.88369
# Epoch 85/100, Training loss: 1.95821
# Epoch 86/100, Training loss: 1.86229
# Epoch 87/100, Training loss: 1.90888
# Epoch 88/100, Training loss: 1.88491
# Epoch 89/100, Training loss: 2.23223
# Epoch 90/100, Training loss: 1.86837
# Epoch 91/100, Training loss: 1.94487
# Epoch 92/100, Training loss: 2.10289
# Epoch 93/100, Training loss: 1.92230
# Epoch 94/100, Training loss: 1.86361
# Epoch 95/100, Training loss: 2.02702
# Epoch 96/100, Training loss: 2.01766
# Epoch 97/100, Training loss: 1.87948
# Epoch 98/100, Training loss: 1.86302
# Epoch 99/100, Training loss: 2.11350
# Epoch 100/100, Training loss: 2.18369
# Epoch 1/100, Training loss: 3.46060
# Epoch 2/100, Training loss: 1.98583
# Epoch 3/100, Training loss: 2.21994
# Epoch 4/100, Training loss: 1.96682
# Epoch 5/100, Training loss: 2.42338
# Epoch 6/100, Training loss: 2.39770
# Epoch 7/100, Training loss: 2.02088
# Epoch 8/100, Training loss: 1.93775
# Epoch 9/100, Training loss: 1.93722
# Epoch 10/100, Training loss: 1.87937
# Epoch 11/100, Training loss: 1.86715
# Epoch 12/100, Training loss: 2.43027
# Epoch 13/100, Training loss: 2.02438
# Epoch 14/100, Training loss: 2.21088
# Epoch 15/100, Training loss: 1.89736
# Epoch 16/100, Training loss: 1.87008
# Epoch 17/100, Training loss: 1.90382
# Epoch 18/100, Training loss: 1.86247
# Epoch 19/100, Training loss: 1.87833
# Epoch 20/100, Training loss: 1.86600
# Epoch 21/100, Training loss: 1.90656
# Epoch 22/100, Training loss: 2.67672
# Epoch 23/100, Training loss: 2.10026
# Epoch 24/100, Training loss: 1.88456
# Epoch 25/100, Training loss: 1.91359
# Epoch 26/100, Training loss: 1.86612
# Epoch 27/100, Training loss: 1.86191
# Epoch 28/100, Training loss: 1.94367
# Epoch 29/100, Training loss: 2.03542
# Epoch 30/100, Training loss: 1.91678
# Epoch 31/100, Training loss: 1.91558
# Epoch 32/100, Training loss: 1.87195
# Epoch 33/100, Training loss: 1.88117
# Epoch 34/100, Training loss: 1.89296
# Epoch 35/100, Training loss: 1.90050
# Epoch 36/100, Training loss: 1.88718
# Epoch 37/100, Training loss: 1.89479
# Epoch 38/100, Training loss: 1.91442
# Epoch 39/100, Training loss: 1.88001
# Epoch 40/100, Training loss: 1.95058
# Epoch 41/100, Training loss: 1.87415
# Epoch 42/100, Training loss: 1.91200
# Epoch 43/100, Training loss: 1.92461
# Epoch 44/100, Training loss: 1.92288
# Epoch 45/100, Training loss: 1.89300
# Epoch 46/100, Training loss: 2.08324
# Epoch 47/100, Training loss: 1.89316
# Epoch 48/100, Training loss: 2.17120
# Epoch 49/100, Training loss: 3.54500
# Epoch 50/100, Training loss: 3.18290
# Epoch 51/100, Training loss: 2.31994
# Epoch 52/100, Training loss: 1.90675
# Epoch 53/100, Training loss: 1.88887
# Epoch 54/100, Training loss: 1.91242
# Epoch 55/100, Training loss: 1.87882
# Epoch 56/100, Training loss: 1.89405
# Epoch 57/100, Training loss: 2.07180
# Epoch 58/100, Training loss: 1.87616
# Epoch 59/100, Training loss: 1.89522
# Epoch 60/100, Training loss: 1.86881
# Epoch 61/100, Training loss: 2.03345
# Epoch 62/100, Training loss: 1.88476
# Epoch 63/100, Training loss: 1.95317
# Epoch 64/100, Training loss: 1.88658
# Epoch 65/100, Training loss: 3.57353
# Epoch 66/100, Training loss: 2.10834
# Epoch 67/100, Training loss: 1.92190
# Epoch 68/100, Training loss: 1.85529
# Epoch 69/100, Training loss: 1.92653
# Epoch 70/100, Training loss: 1.93319
# Epoch 71/100, Training loss: 1.88489
# Epoch 72/100, Training loss: 1.89396
# Epoch 73/100, Training loss: 1.87838
# Epoch 74/100, Training loss: 1.98521
# Epoch 75/100, Training loss: 1.94246
# Epoch 76/100, Training loss: 1.86924
# Epoch 77/100, Training loss: 1.85428
# Epoch 78/100, Training loss: 2.45727
# Epoch 79/100, Training loss: 2.02035
# Epoch 80/100, Training loss: 1.90042
# Epoch 81/100, Training loss: 1.92690
# Epoch 82/100, Training loss: 1.97296
# Epoch 83/100, Training loss: 1.89225
# Epoch 84/100, Training loss: 2.45863
# Epoch 85/100, Training loss: 3.84052
# Epoch 86/100, Training loss: 1.87517
# Epoch 87/100, Training loss: 1.92903
# Epoch 88/100, Training loss: 1.86887
# Epoch 89/100, Training loss: 1.86042
# Epoch 90/100, Training loss: 1.91042
# Epoch 91/100, Training loss: 2.06620
# Epoch 92/100, Training loss: 2.06980
# Epoch 93/100, Training loss: 1.88132
# Epoch 94/100, Training loss: 1.96074
# Epoch 95/100, Training loss: 2.08347
# Epoch 96/100, Training loss: 2.20588
# Epoch 97/100, Training loss: 2.38788
# Epoch 98/100, Training loss: 1.94402
# Epoch 99/100, Training loss: 1.93831
# Epoch 100/100, Training loss: 2.42614
# Epoch 1/100, Training loss: 4.42293
# Epoch 2/100, Training loss: 1.93446
# Epoch 3/100, Training loss: 1.96282
# Epoch 4/100, Training loss: 2.16259
# Epoch 5/100, Training loss: 3.55779
# Epoch 6/100, Training loss: 3.52426
# Epoch 7/100, Training loss: 3.04280
# Epoch 8/100, Training loss: 2.15061
# Epoch 9/100, Training loss: 1.86745
# Epoch 10/100, Training loss: 1.90260
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-423e43689f30> in <module>
#      91             # += function: Adds the running_loss (0) with loss.item and assigns back to running_loss
#      92         else:
# ---> 93             print("Epoch {}/{}, Training loss: {:.5f}".format(e+1, epochs, running_loss/len(trainloader)))
#      94
#      95     # Apply the model to the testing dataset
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#      39
#      40     def write(self, text):
# ---> 41         self.__convertor.write(text)
#      42
#      43     def isatty(self):
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#     160     def write(self, text):
#     161         if self.strip or self.convert:
# --> 162             self.write_and_convert(text)
#     163         else:
#     164             self.wrapped.write(text)
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_and_convert(self, text)
#     188             self.convert_ansi(*match.groups())
#     189             cursor = end
# --> 190         self.write_plain_text(text, cursor, len(text))
#     191
#     192
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_plain_text(self, text, start, end)
#     193     def write_plain_text(self, text, start, end):
#     194         if start < end:
# --> 195             self.wrapped.write(text[start:end])
#     196             self.wrapped.flush()
#     197
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~\Anaconda3\lib\site-packages\zmq\sugar\socket.py in send(self, data, flags, copy, track, routing_id, group)
#     390                                  copy_threshold=self.copy_threshold)
#     391             data.group = group
# --> 392         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     393
#     394     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~\Anaconda3\lib\site-packages\zmq\backend\cython\checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # **Determine LOOCV Mean Error**

# %%
percent_correct = sum(results_ls)
percent_correct = percent_correct/len(mcTrain_y)*100
percent_incorrect = 100 - percent_correct
percent_incorrect = round(percent_incorrect, 1)
#print('Percent Error', round(percent_incorrect, 1))

# %% [markdown]
# # **Incorrect Predictions**

# %%
## Remove the correct elements from the ls to faciliate transforming this list into a dataframe
# First, concatenate all incorrect list elements and format into dataframe
incorrect_res = np.concatenate(incorrect_ls)
incorrect_res = pd.DataFrame(incorrect_res)
incorrect_res.columns = ['diagnosis']
incorrect_res = incorrect_res[incorrect_res.diagnosis != 999] # 999 are the results that were correct - we remove these

# Count number of incorrect predictions by diagnosis
incorrect_pred = incorrect_res.groupby(['diagnosis']).size()
incorrect_pred = pd.DataFrame(incorrect_pred)
incorrect_pred.columns = ['Count']

# Convert the index to the first column and change the numebr to categorical variables
incorrect_pred.reset_index(level=0, inplace=True)
incorrect_pred['diagnosis'] = incorrect_pred['diagnosis'].map({0: 'HEA', 1: 'CRC', 2: 'ESCA', 3: 'HCC', 4: 'STAD', 5:'GBM', 6:'BRCA'})

# Add a column with the number of cases in each class
mcTrain_y['diagnosis'] = mcTrain_y['diagnosis'].map({0: 'HEA', 1: 'CRC', 2: 'ESCA', 3: 'HCC', 4: 'STAD', 5:'GBM', 6:'BRCA'})
class_size = mcTrain_y.groupby(['diagnosis']).size()
class_size = pd.DataFrame(class_size)
class_size.columns = ['Sample_n']

# bind class_size to the pred df diagnoses
incorrect_pred = pd.merge(incorrect_pred, class_size, how="left", on="diagnosis") 

# Calculate the percent error for each class
incorrect_pred['Count_Perc_Incorrect'] = incorrect_pred['Count']/incorrect_pred['Sample_n']
incorrect_pred['Count_Perc_Incorrect'] = incorrect_pred['Count_Perc_Incorrect'].multiply(100)

# %% [markdown]
# # **Correct Predictions**

# %%
## Remove the incorrect elements from the ls to faciliate transforming this list into a dataframe
# First, concatenate all incorrect list elements and format into dataframe
correct_res = np.concatenate(correct_ls)
correct_res = pd.DataFrame(correct_res)
correct_res.columns = ['diagnosis']
correct_res = correct_res[correct_res.diagnosis != 999] # 999 are the results that were incorrect - we remove these

# Count number of correct predictions by diagnosis
correct_pred = correct_res.groupby(['diagnosis']).size()
correct_pred = pd.DataFrame(correct_pred)
correct_pred.columns = ['Count']

# Convert the index to the first column and change the numebr to categorical variables
correct_pred.reset_index(level=0, inplace=True)
correct_pred['diagnosis'] = correct_pred['diagnosis'].map({0: 'HEA', 1: 'CRC', 2: 'ESCA', 3: 'HCC', 4: 'STAD', 5:'GBM', 6:'BRCA'})

# Add a column with the number of cases in each class
class_size = mcTrain_y.groupby(['diagnosis']).size()
class_size = pd.DataFrame(class_size)
class_size.columns = ['Sample_n']

# bind class_size to the pred df diagnoses
correct_pred = pd.merge(correct_pred, class_size, how="left", on="diagnosis") 

# Calculate the percent correct for each class
correct_pred['Count_Perc_Correct'] = correct_pred['Count']/correct_pred['Sample_n']
correct_pred['Count_Perc_Correct'] = correct_pred['Count_Perc_Correct'].multiply(100)

# %% [markdown]
# # **Save Predictions**

# %%
# convert float to string in order to save as a txt file
percent_error = '     Percent Error'
percent_error = str(percent_error)
percent_incorrect = str(percent_incorrect)

# save the pre-specified summary of the experiment which includes parameter spe$
summary = summary + percent_error + percent_incorrect

#Feb 21, 2020 Test
print(summary)
print(correct_pred)
