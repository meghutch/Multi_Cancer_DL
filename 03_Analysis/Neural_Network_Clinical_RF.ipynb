# %% [markdown]
# # **Methylation Biomarkers for Predicting Cancer**
#
# ## **Deep Learning Approaches for Cancer Classification - Clinical Data + RF Features**
#
# **Author:** Meg Hutch
#
# **Date:** March 1, 2020
#
# **Objective:** Use neural networks to classify cancer type.
#
# **Note:** In this version, I will only test the ability of methylation levels to classify cancer types. I will not include phenotypic data for now. Additionally, this version has our data split 70% for training and 30% for testing. The 70% training data will undergo leave-one-out-cross-fold validation to tune hyperparameters prior to testing final performance on the 30% test set.
#
# Note: This is the new version of the script where we normalize gene counts using DEseq2 in the initial pre-processing script in R. This provided more than double the number of Principal Components that make up 90% of the variance (157). Regardless, we will begin running the deep learning classifier on the revised data.
#
# Update: This script will include the clinical data

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns

# %%
# set working directory for git hub
import os
os.chdir('/projects/p31049/Multi_Cancer_DL/')
#os.chdir('C:\\Users\\User\\Box Sync/Projects/Multi_Cancer_DL/')
os. getcwd()
# Out:
# '/projects/p31049/Multi_Cancer_DL'

# %% [markdown]
# **Import Training, Testing, and Principal component data**

# %% [markdown]
# **Full Dataset**

# %%
# Training set
mcTrain_x = pd.read_csv('02_Processed_Data/Final_Datasets/mcTrain_x_Full_70_30.csv')
mcTrain_y = pd.read_csv('02_Processed_Data/Final_Datasets/mcTrain_y_Full_70_30.csv')
# Testing set
mcTest_x = pd.read_csv('02_Processed_Data/Final_Datasets/mcTest_x_Full_70_30.csv')
mcTest_y = pd.read_csv('02_Processed_Data/Final_Datasets/mcTest_y_Full_70_30.csv')

# Random Forest Features
rf_feats = pd.read_csv('02_Processed_Data/Final_Datasets/rf_100feats_FULL_70_30.csv')

# %%
#mcTrain_y.head()
#pca_Train.head()
#rf_feats.head()

# %% [markdown]
# # **Pre-Process Data**

# %%
# rename the first column name of the rf_feats dataframes
rf_feats.rename(columns={'Unnamed: 0':'Gene'}, inplace=True)

# %% [markdown]
# **Remove the Importance Column**

# %%
rf_feats = rf_feats.drop(columns=["0"])

# %% [markdown]
# **Convert id to index**

# %%
mcTrain_x = mcTrain_x.set_index('id')
mcTrain_y = mcTrain_y.set_index('id')

mcTest_x = mcTest_x.set_index('id')
mcTest_y = mcTest_y.set_index('id')

# %% [markdown]
# **Create seperate DF with only Clinical Variables**

# %%
mcTrain_clinical_x = mcTrain_x[['dilute_library_concentration', 'age', 'gender', 'frag_mean']]
mcTest_clinical_x = mcTest_x[['dilute_library_concentration', 'age', 'gender', 'frag_mean']]

# %% [markdown]
# **Keep only the Genes that were in the rf_feats**

# %%
# Create a list of the Genes to keep
rf_genes = rf_feats.Gene
# convert to df
rf_genes = pd.DataFrame(rf_genes)
# set Gene as an index
rf_genes = rf_genes.set_index('Gene')
# Create a list of the gene names
rf_genes = list(rf_genes.index)
rf_genes
# Out:
# ['LMO7DN',
#  'EVC',
#  'DPYSL2',
#  'EPB41',
#  'G6PC',
#  'HSPB8',
#  'PRELID2',
#  'MED18',
#  'ADGRG5',
#  'PAQR9',
#  'CCDC13',
#  'ADAM2',
#  'CECR2',
#  'APOL3',
#  'NUPR1',
#  'PRKAB2',
#  'PPP2R5C',
#  'ZHX2',
#  'TRIM64B',
#  'AKR1B10',
#  'METAP1',
#  'POTEM',
#  'BAG5',
#  'OR9Q1',
#  'C8orf4',
#  'XRCC4',
#  'FAM134C',
#  'PAFAH1B1',
#  'POMGNT2',
#  'C19orf66',
#  'TBC1D2B',
#  'CCM2',
#  'NOVA1',
#  'STAU1',
#  'TOP1',
#  'CELA2A',
#  'RNF214',
#  'DIO2',
#  'SAE1',
#  'LHX4',
#  'TRIM68',
#  'MARC1',
#  'ATP5S',
#  'SLC52A1',
#  'GGCX',
#  'UBE3D',
#  'CKAP2',
#  'TP53I13',
#  'TMCO5A',
#  'PARD6A',
#  'GATB',
#  'CAP2',
#  'ARID1B',
#  'SPRED1',
#  'NCEH1',
#  'PCNP',
#  'MYRFL',
#  'DAAM2',
#  'PRR13',
#  'GFOD2',
#  'GLE1',
#  'NOP9',
#  'RUFY2',
#  'PREX2',
#  'DSCR3',
#  'LINGO2',
#  'CEACAM8',
#  'ATP6V0A2',
#  'RBM4',
#  'GRIA4',
#  'TCP11L1',
#  'RGS9',
#  'COA7',
#  'RP11-298I3.5',
#  'HBQ1',
#  'PCLO',
#  'GDI2',
#  'NPRL3',
#  'IL31RA',
#  'NPNT',
#  'LYSMD3',
#  'ZSCAN29',
#  'NAV2',
#  'APOE',
#  'GABRP',
#  'KLF15',
#  'SEMA7A',
#  'RAB25',
#  'RAF1',
#  'FAIM',
#  'GAS2L3',
#  'AL590714.1',
#  'RPL29',
#  'ORM1',
#  'RAP1B',
#  'JAM2',
#  'TMPO',
#  'PDX1',
#  'HOXA1',
#  'FAT4']

# %%
mcTrain_x = mcTrain_x[rf_genes]
mcTest_x = mcTest_x[rf_genes]
mcTrain_x
# Out:
#         LMO7DN         EVC       DPYSL2        EPB41        G6PC       HSPB8  \
# id
# 1    69.438420  274.690219  1748.214328  2400.731241  182.786428  164.405670
# 2    73.950495  262.808681  1713.376078  2436.953227  220.713784  126.284691
# 3    80.060550  179.828312  1911.599596  2321.755952  230.328044  161.352801
# 4    92.428914  231.072286  1754.182802  2466.082100  163.225530  153.392667
# 5    80.767629  212.265338  1816.937895  2435.711381  196.912814  156.195249
# ..         ...         ...          ...          ...         ...         ...
# 238  69.810532  152.520836  1575.289828  2644.453300  214.743267  128.238912
# 239  90.682730  193.456490  1774.358746  2449.945083  204.036142  139.046852
# 240  69.946359  137.394633  1858.574676  2430.635967  184.025539  152.383139
# 241  97.415283  200.919021  1775.393535  2520.620451  204.572095  161.952908
# 242  77.361788  290.841151  1785.196695  2296.372051  203.686732  132.200523
#
#          PRELID2       MED18      ADGRG5       PAQR9  ...      GAS2L3  \
# id                                                    ...
# 1    1325.456891  136.834533  418.672824  118.453775  ...  266.520993
# 2    1399.370900  137.661690  469.870067   79.638994  ...  211.612185
# 3    1526.077255  115.779872  493.912009   71.438645  ...  216.779336
# 4    1492.628640  129.793795  469.027576   93.412201  ...  243.855008
# 5    1632.040100  101.460162  624.113494   83.437633  ...  220.942852
# ..           ...         ...         ...         ...  ...         ...
# 238  1358.270131  140.379874  504.608736  106.992228  ...  179.838001
# 239  1413.139206  116.376170  510.846044   81.614457  ...  266.002674
# 240  1349.798185   94.094506  540.418891   84.934864  ...  195.683266
# 241  1478.276922  135.163705  500.471017   80.367609  ...  226.490533
# 242  1227.995971  130.241997  521.947251   97.926313  ...  241.877994
#
#      AL590714.1      RPL29       ORM1        RAP1B        JAM2        TMPO  \
# id
# 1     26.549984  10.211532  23.486524  1477.608722  738.293785  695.405349
# 2     32.993298  10.239299  28.442498  1457.393596  757.708146  696.272350
# 3     23.402315  11.085307  36.951023  1416.455886  807.995705  615.850385
# 4     34.415021   9.832863  34.415021  1595.873704  812.194503  702.066435
# 5     29.370047  10.680017  28.702546  1469.837342  790.321259  570.045908
# ..          ...        ...        ...          ...         ...         ...
# 238   17.452633  12.140962  41.734557  1475.126891  729.216534  663.200053
# 239   45.341365   9.068273  33.250334  1588.459150  890.202131  648.381518
# 240   25.813537  15.821200  15.821200  1385.604059  869.333316  695.300114
# 241   31.659967  10.959219  30.442276  1687.719780  871.866784  711.131567
# 242   30.357157  23.502315  25.460842  1602.074489  607.143144  770.680087
#
#           PDX1      HOXA1         FAT4
# id
# 1    21.444218  27.571137  1008.899390
# 2    17.065499  18.203199   932.913934
# 3    23.402315  20.938913  1037.092049
# 4    14.749295  25.565444   872.174969
# 5    18.022529  27.367544   729.578662
# ..         ...        ...          ...
# 238  12.899772  12.140962   887.807851
# 239  12.091031  21.159304   926.475223
# 240  12.490421  24.148148   926.789254
# 241   9.741528  17.047675  1033.819692
# 242  30.357157  25.460842   813.767665
#
# [242 rows x 100 columns]

# %%
# merge PCs with clinical/phenotypic data
mcTrain_x = pd.merge(mcTrain_clinical_x, mcTrain_x, how="left", on="id") 
mcTest_x = pd.merge(mcTest_clinical_x, mcTest_x, how="left", on="id")

# %% [markdown]
# **Drop the library concentraion (should have already controlled for this perhaps with deseq2 normalization?); Just simply keep demographic data for these experiments!**

# %%
mcTrain_x = mcTrain_x.drop(columns=["dilute_library_concentration"])
mcTest_x = mcTest_x.drop(columns=["dilute_library_concentration"])

# %% [markdown]
# **Normalize Data**
#
# From my reading, it seems that normalization, as opposed to standardization, is the more optimal approach when data is not normally distributed.
#
# Normalization will rescale our values into range of [0,1]. We need to normalize both the training and test sets

# %%
from sklearn.preprocessing import MinMaxScaler

# The normalization function to be performed will convert dataframe into array, for this reason we'll have to convert it back
# Thus, need to store columns and index
# select all columns
cols = list(mcTrain_x.columns.values)
index_train = list(mcTrain_x.index)
index_test = list(mcTest_x.index)

# Normalize data
scaler = MinMaxScaler()
mcTrain_x = scaler.fit_transform(mcTrain_x.astype(np.float))
mcTest_x = scaler.fit_transform(mcTest_x.astype(np.float))

# Convert back to dataframe
mcTrain_x = pd.DataFrame(mcTrain_x, columns = cols, index = index_train)
mcTest_x = pd.DataFrame(mcTest_x, columns = cols, index = index_test)

# %% [markdown]
# # Construct & Run Neural Network

# %%
# Import PyTorch packages
import torch
from torch import nn
#from torchvision import datasets, transforms
from torch import optim
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data.dataloader import DataLoader
from torch.utils.data import TensorDataset
import torch.nn.functional as F
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %%
mcTrain_x.shape
# Out:
# (242, 103)

# %%
# define list for results
results_ls = []

# Where we will store correct/incorrect classifications
incorrect_ls = []
correct_ls = []

# Leave-one-out-cross-fold validation function - the for loop will iterate through the dataset, removing one sample (patient)
# at a time in order to create k training and test datasets (where k = number of total samples) always with one sample missing
for index in range (0, 242):
#for index in range (0, 212): # 212 observations when we downsample healthy patients 
    # X - features; 
    mcTrain_xy_drop = mcTrain_x.drop(mcTrain_x.index[index]) # add 'drop'suffix so we can differentiate the df with index and the array that will be created in next line
    mcTrain_xy = np.array(mcTrain_xy_drop, dtype = "float32")
    
    # y - target/outputs
    mcTrain_yz_drop = mcTrain_y.drop(mcTrain_y.index[index]) 
    mcTrain_yz = np.array(mcTrain_yz_drop, dtype = "float32")
    
    # reformat into tensors
    xb = torch.from_numpy(mcTrain_xy)
    yb = torch.from_numpy(mcTrain_yz)
    
    # squeeze - function is used when we want to remove single-dimensional entries from the shape of an array.
    yb = yb.squeeze(1) 
    
    # subset the equivalent test set
    mcTrain_test_x_drop = mcTrain_x.iloc[[index]] # add 'drop'suffix so we can differentiate the df with index and the array that will be created in next line
    mcTrain_test_x = np.array(mcTrain_test_x_drop, dtype = "float32")
            
    # y - targets/outputs
    mcTrain_test_y_drop = mcTrain_y.iloc[[index]]
    mcTrain_test_y = np.array(mcTrain_test_y_drop, dtype = "float32")
        
    # Convert arrays into tensors
    test_xb = torch.from_numpy(mcTrain_test_x)
    test_yb = torch.from_numpy(mcTrain_test_y)
    
    # Define the batchsize
    batch_size = 32

    # Combine the arrays
    trainloader = TensorDataset(xb, yb)
    
    # Training Loader
    trainloader = DataLoader(trainloader, batch_size, shuffle=True)
    
    ## Build the Model and define hyperparameters
    
    # Set parameters for grid search
    #lrs = [1e-2, 1e-3, 1e-4]
    #epochs = [100, 150, 200, 250]
    
    # summarize experiment with changed parameters
    summary = ('Hidden Layers: 50, LR: 0.001, Epochs: 600')
    
    # Define the model with hidden layers
    model = nn.Sequential(nn.Linear(103, 50),
                          nn.ReLU(),
                          nn.Linear(50, 7))
                      
    # Set Stoachastic Gradient Descent Optimizer and the learning rate
    #optimizer = optim.SGD(model.parameters(), lr=0.003)

    # Set Adam optimizer: similar to stochastic gradient descent, but uses momentum which can speed up the actual fitting process, and it also adjusts the learning rate for each of the individual parameters in the model
    optimizer = optim.Adam(model.parameters(), lr=0.10,  weight_decay=0.01) # we can also change momentum parameter

    # loss function
    criterion = nn.CrossEntropyLoss() #don't use with softmax or sigmoid- PyTorch manual indicates "This criterion combines nn.LogSoftmax() and nn.NLLLoss() in one single class."
    
    # Set epochs - number of times the entire dataset will pass through the network
    epochs = 100
    for e in range(epochs):
        # Define running loss as 0
        running_loss = 0
        
        # Run the model for each xb, yb in the trainloader. For the number of epochs specified, the 
        for xb, yb in trainloader:
            # clear gradients - otherwise they are stored
            optimizer.zero_grad()
            # Training pass
            output = model.forward(xb)
            # caluclate loss calculated from the model output compared to the labels
            loss = criterion(output, yb.long()) 
            # backpropagate the loss
            loss.backward()
            # step function to update the weights
            optimizer.step()
        
            running_loss += loss.item() # loss.item() gets the scalar value held in the loss. 
            # += function: Adds the running_loss (0) with loss.item and assigns back to running_loss
        #else:
        #    print("Epoch {}/{}, Training loss: {:.5f}".format(e+1, epochs, running_loss/len(trainloader)))

    # Apply the model to the testing dataset
    # Thus will enable us to see the predictions for each class
    ps = model(test_xb)
    #print('Network Probabilities', ps)
    
    # Obtain the top prediction
    top_p, top_class = ps.topk(1, dim=1)
    #print('top prediction', top_p)
    #print('true vals', test_yb[:10])
        
    # Drop the grad by using detach
    top_p = top_p.detach().numpy()
    top_class = top_class.detach().numpy()

    # convert to integers
    top_class = top_class.astype(np.int)
    test_yb = test_yb.numpy()
    test_yb = test_yb.astype(np.int)
    
    #print('top class', top_class[:10])
    #print('prediction:', top_class)
    #print('true:', test_yb)
                
    # compare top_class to test_yb
    if top_class == test_yb:                
        results = 1 # prediction and true value are equal
    else: 
        results = 0
    
    # Create if-else statements to identify which classes are being classified correctly/incorrectly
    if results == 0:
        incorrect = test_yb
    else: 
        incorrect = np.array([[999]], dtype=int)
        
    if results == 1:
        correct = test_yb
    else: 
        correct = np.array([[999]], dtype=int)
    #print('Results:', results)
    
    results_ls.append(results)
    incorrect_ls.append(incorrect)
    correct_ls.append(correct)
    #print(results_ls)
# Out:
# Epoch 1/100, Training loss: 3.30442
# Epoch 2/100, Training loss: 2.11192
# Epoch 3/100, Training loss: 1.96899
# Epoch 4/100, Training loss: 1.91402
# Epoch 5/100, Training loss: 1.88137
# Epoch 6/100, Training loss: 1.97218
# Epoch 7/100, Training loss: 1.90056
# Epoch 8/100, Training loss: 1.95280
# Epoch 9/100, Training loss: 2.27232
# Epoch 10/100, Training loss: 2.06005
# Epoch 11/100, Training loss: 1.83292
# Epoch 12/100, Training loss: 2.39840
# Epoch 13/100, Training loss: 1.94495
# Epoch 14/100, Training loss: 1.88024
# Epoch 15/100, Training loss: 1.86363
# Epoch 16/100, Training loss: 1.82814
# Epoch 17/100, Training loss: 1.93240
# Epoch 18/100, Training loss: 1.81629
# Epoch 19/100, Training loss: 1.95443
# Epoch 20/100, Training loss: 1.85725
# Epoch 21/100, Training loss: 2.06775
# Epoch 22/100, Training loss: 1.88020
# Epoch 23/100, Training loss: 1.85579
# Epoch 24/100, Training loss: 1.92707
# Epoch 25/100, Training loss: 1.91390
# Epoch 26/100, Training loss: 1.85030
# Epoch 27/100, Training loss: 1.88713
# Epoch 28/100, Training loss: 1.84947
# Epoch 29/100, Training loss: 1.80159
# Epoch 30/100, Training loss: 1.85778
# Epoch 31/100, Training loss: 1.86505
# Epoch 32/100, Training loss: 1.83956
# Epoch 33/100, Training loss: 1.90612
# Epoch 34/100, Training loss: 1.84346
# Epoch 35/100, Training loss: 1.79131
# Epoch 36/100, Training loss: 1.90827
# Epoch 37/100, Training loss: 1.92299
# Epoch 38/100, Training loss: 1.86289
# Epoch 39/100, Training loss: 1.81051
# Epoch 40/100, Training loss: 1.78341
# Epoch 41/100, Training loss: 1.82125
# Epoch 42/100, Training loss: 1.94320
# Epoch 43/100, Training loss: 1.73563
# Epoch 44/100, Training loss: 1.79739
# Epoch 45/100, Training loss: 1.85767
# Epoch 46/100, Training loss: 1.73284
# Epoch 47/100, Training loss: 1.86126
# Epoch 48/100, Training loss: 1.78705
# Epoch 49/100, Training loss: 1.85866
# Epoch 50/100, Training loss: 1.98375
# Epoch 51/100, Training loss: 1.91859
# Epoch 52/100, Training loss: 1.90304
# Epoch 53/100, Training loss: 1.88040
# Epoch 54/100, Training loss: 1.83091
# Epoch 55/100, Training loss: 1.79152
# Epoch 56/100, Training loss: 1.86529
# Epoch 57/100, Training loss: 1.79496
# Epoch 58/100, Training loss: 1.75997
# Epoch 59/100, Training loss: 1.88151
# Epoch 60/100, Training loss: 1.83982
# Epoch 61/100, Training loss: 1.84628
# Epoch 62/100, Training loss: 1.85642
# Epoch 63/100, Training loss: 2.02527
# Epoch 64/100, Training loss: 1.90002
# Epoch 65/100, Training loss: 2.01324
# Epoch 66/100, Training loss: 1.86755
# Epoch 67/100, Training loss: 1.86825
# Epoch 68/100, Training loss: 1.86441
# Epoch 69/100, Training loss: 1.88467
# Epoch 70/100, Training loss: 1.98808
# Epoch 71/100, Training loss: 1.93744
# Epoch 72/100, Training loss: 1.84630
# Epoch 73/100, Training loss: 1.90035
# Epoch 74/100, Training loss: 1.82654
# Epoch 75/100, Training loss: 1.93542
# Epoch 76/100, Training loss: 1.89217
# Epoch 77/100, Training loss: 1.89276
# Epoch 78/100, Training loss: 1.90667
# Epoch 79/100, Training loss: 1.88751
# Epoch 80/100, Training loss: 1.87459
# Epoch 81/100, Training loss: 1.83121
# Epoch 82/100, Training loss: 1.81062
# Epoch 83/100, Training loss: 1.81322
# Epoch 84/100, Training loss: 1.85679
# Epoch 85/100, Training loss: 1.85413
# Epoch 86/100, Training loss: 1.85858
# Epoch 87/100, Training loss: 1.83717
# Epoch 88/100, Training loss: 1.85180
# Epoch 89/100, Training loss: 1.78269
# Epoch 90/100, Training loss: 1.81721
# Epoch 91/100, Training loss: 1.92651
# Epoch 92/100, Training loss: 1.90345
# Epoch 93/100, Training loss: 1.87811
# Epoch 94/100, Training loss: 1.82533
# Epoch 95/100, Training loss: 1.86507
# Epoch 96/100, Training loss: 1.80415
# Epoch 97/100, Training loss: 2.17141
# Epoch 98/100, Training loss: 1.88663
# Epoch 99/100, Training loss: 1.83903
# Epoch 100/100, Training loss: 1.94333
# [0]
# Epoch 1/100, Training loss: 3.58582
# Epoch 2/100, Training loss: 2.00489
# Epoch 3/100, Training loss: 1.87338
# Epoch 4/100, Training loss: 1.85361
# Epoch 5/100, Training loss: 1.84307
# Epoch 6/100, Training loss: 1.89568
# Epoch 7/100, Training loss: 1.87047
# Epoch 8/100, Training loss: 1.89162
# Epoch 9/100, Training loss: 1.78163
# Epoch 10/100, Training loss: 1.65533
# Epoch 11/100, Training loss: 1.71451
# Epoch 12/100, Training loss: 1.60921
# Epoch 13/100, Training loss: 1.57978
# Epoch 14/100, Training loss: 1.56157
# Epoch 15/100, Training loss: 1.42657
# Epoch 16/100, Training loss: 1.56110
# Epoch 17/100, Training loss: 1.42815
# Epoch 18/100, Training loss: 1.43360
# Epoch 19/100, Training loss: 1.39112
# Epoch 20/100, Training loss: 1.44042
# Epoch 21/100, Training loss: 1.45635
# Epoch 22/100, Training loss: 1.34594
# Epoch 23/100, Training loss: 1.32907
# Epoch 24/100, Training loss: 1.19346
# Epoch 25/100, Training loss: 2.04002
# Epoch 26/100, Training loss: 1.44486
# Epoch 27/100, Training loss: 1.37049
# Epoch 28/100, Training loss: 1.31593
# Epoch 29/100, Training loss: 1.24305
# Epoch 30/100, Training loss: 1.23612
# Epoch 31/100, Training loss: 1.19053
# Epoch 32/100, Training loss: 1.25908
# Epoch 33/100, Training loss: 1.14731
# Epoch 34/100, Training loss: 1.23217
# Epoch 35/100, Training loss: 1.14443
# Epoch 36/100, Training loss: 1.23820
# Epoch 37/100, Training loss: 1.31549
# Epoch 38/100, Training loss: 1.50014
# Epoch 39/100, Training loss: 1.23878
# Epoch 40/100, Training loss: 1.30956
# Epoch 41/100, Training loss: 1.34611
# Epoch 42/100, Training loss: 1.32860
# Epoch 43/100, Training loss: 1.23346
# Epoch 44/100, Training loss: 1.35811
# Epoch 45/100, Training loss: 1.79478
# Epoch 46/100, Training loss: 1.34928
# Epoch 47/100, Training loss: 1.42698
# Epoch 48/100, Training loss: 1.30246
# Epoch 49/100, Training loss: 1.42763
# Epoch 50/100, Training loss: 1.59301
# Epoch 51/100, Training loss: 1.44733
# Epoch 52/100, Training loss: 1.28584
# Epoch 53/100, Training loss: 1.21695
# Epoch 54/100, Training loss: 1.34413
# Epoch 55/100, Training loss: 1.21757
# Epoch 56/100, Training loss: 1.23374
# Epoch 57/100, Training loss: 1.20682
# Epoch 58/100, Training loss: 1.25279
# Epoch 59/100, Training loss: 1.24651
# Epoch 60/100, Training loss: 1.19728
# Epoch 61/100, Training loss: 1.65800
# Epoch 62/100, Training loss: 1.46448
# Epoch 63/100, Training loss: 1.27964
# Epoch 64/100, Training loss: 1.52013
# Epoch 65/100, Training loss: 1.29113
# Epoch 66/100, Training loss: 1.28947
# Epoch 67/100, Training loss: 1.39996
# Epoch 68/100, Training loss: 1.35887
# Epoch 69/100, Training loss: 1.48831
# Epoch 70/100, Training loss: 1.36440
# Epoch 71/100, Training loss: 2.50996
# Epoch 72/100, Training loss: 2.31592
# Epoch 73/100, Training loss: 2.05158
# Epoch 74/100, Training loss: 1.97926
# Epoch 75/100, Training loss: 1.74948
# Epoch 76/100, Training loss: 1.75406
# Epoch 77/100, Training loss: 1.67392
# Epoch 78/100, Training loss: 1.60916
# Epoch 79/100, Training loss: 1.59742
# Epoch 80/100, Training loss: 1.57839
# Epoch 81/100, Training loss: 1.96201
# Epoch 82/100, Training loss: 1.60296
# Epoch 83/100, Training loss: 1.57095
# Epoch 84/100, Training loss: 1.55404
# Epoch 85/100, Training loss: 1.58416
# Epoch 86/100, Training loss: 1.67378
# Epoch 87/100, Training loss: 1.68541
# Epoch 88/100, Training loss: 1.71361
# Epoch 89/100, Training loss: 1.48315
# Epoch 90/100, Training loss: 1.48619
# Epoch 91/100, Training loss: 1.60313
# Epoch 92/100, Training loss: 1.67581
# Epoch 93/100, Training loss: 1.50733
# Epoch 94/100, Training loss: 1.53249
# Epoch 95/100, Training loss: 1.55108
# Epoch 96/100, Training loss: 1.55731
# Epoch 97/100, Training loss: 1.46278
# Epoch 98/100, Training loss: 1.45745
# Epoch 99/100, Training loss: 1.67028
# Epoch 100/100, Training loss: 1.62293
# [0, 0]
# Epoch 1/100, Training loss: 4.53559
# Epoch 2/100, Training loss: 1.94006
# Epoch 3/100, Training loss: 1.88184
# Epoch 4/100, Training loss: 1.85155
# Epoch 5/100, Training loss: 1.81453
# Epoch 6/100, Training loss: 1.74725
# Epoch 7/100, Training loss: 1.69753
# Epoch 8/100, Training loss: 1.73823
# Epoch 9/100, Training loss: 1.61955
# Epoch 10/100, Training loss: 1.60773
# Epoch 11/100, Training loss: 1.61648
# Epoch 12/100, Training loss: 1.68306
# Epoch 13/100, Training loss: 1.46972
# Epoch 14/100, Training loss: 1.50375
# Epoch 15/100, Training loss: 1.53838
# Epoch 16/100, Training loss: 1.39102
# Epoch 17/100, Training loss: 1.39679
# Epoch 18/100, Training loss: 1.46221
# Epoch 19/100, Training loss: 1.45567
# Epoch 20/100, Training loss: 1.44717
# Epoch 21/100, Training loss: 1.47626
# Epoch 22/100, Training loss: 1.44669
# Epoch 23/100, Training loss: 1.43888
# Epoch 24/100, Training loss: 1.40494
# Epoch 25/100, Training loss: 1.49078
# Epoch 26/100, Training loss: 1.47392
# Epoch 27/100, Training loss: 1.50610
# Epoch 28/100, Training loss: 1.38653
# Epoch 29/100, Training loss: 1.44738
# Epoch 30/100, Training loss: 1.33219
# Epoch 31/100, Training loss: 1.37798
# Epoch 32/100, Training loss: 1.44653
# Epoch 33/100, Training loss: 1.71137
# Epoch 34/100, Training loss: 1.62248
# Epoch 35/100, Training loss: 1.56335
# Epoch 36/100, Training loss: 1.64157
# Epoch 37/100, Training loss: 1.48459
# Epoch 38/100, Training loss: 1.46099
# Epoch 39/100, Training loss: 1.41866
# Epoch 40/100, Training loss: 1.52463
# Epoch 41/100, Training loss: 1.56321
# Epoch 42/100, Training loss: 1.62099
# Epoch 43/100, Training loss: 1.65454
# Epoch 44/100, Training loss: 1.71527
# Epoch 45/100, Training loss: 1.52064
# Epoch 46/100, Training loss: 1.52929
# Epoch 47/100, Training loss: 1.66222
# Epoch 48/100, Training loss: 1.52375
# Epoch 49/100, Training loss: 1.58123
# Epoch 50/100, Training loss: 1.44801
# Epoch 51/100, Training loss: 1.54625
# Epoch 52/100, Training loss: 1.52452
# Epoch 53/100, Training loss: 1.54358
# Epoch 54/100, Training loss: 1.49524
# Epoch 55/100, Training loss: 1.58259
# Epoch 56/100, Training loss: 1.58327
# Epoch 57/100, Training loss: 1.49599
# Epoch 58/100, Training loss: 1.55804
# Epoch 59/100, Training loss: 1.66117
# Epoch 60/100, Training loss: 1.54133
# Epoch 61/100, Training loss: 1.47580
# Epoch 62/100, Training loss: 1.46119
# Epoch 63/100, Training loss: 1.68575
# Epoch 64/100, Training loss: 1.62345
# Epoch 65/100, Training loss: 1.49584
# Epoch 66/100, Training loss: 1.51551
# Epoch 67/100, Training loss: 1.72617
# Epoch 68/100, Training loss: 1.51184
# Epoch 69/100, Training loss: 1.54400
# Epoch 70/100, Training loss: 1.50301
# Epoch 71/100, Training loss: 1.64967
# Epoch 72/100, Training loss: 1.56258
# Epoch 73/100, Training loss: 1.54342
# Epoch 74/100, Training loss: 1.50474
# Epoch 75/100, Training loss: 2.37165
# Epoch 76/100, Training loss: 2.17905
# Epoch 77/100, Training loss: 1.59290
# Epoch 78/100, Training loss: 1.65029
# Epoch 79/100, Training loss: 2.73178
# Epoch 80/100, Training loss: 1.55741
# Epoch 81/100, Training loss: 1.51383
# Epoch 82/100, Training loss: 1.50039
# Epoch 83/100, Training loss: 1.58180
# Epoch 84/100, Training loss: 1.44267
# Epoch 85/100, Training loss: 1.58533
# Epoch 86/100, Training loss: 1.52773
# Epoch 87/100, Training loss: 1.53713
# Epoch 88/100, Training loss: 1.59966
# Epoch 89/100, Training loss: 1.52651
# Epoch 90/100, Training loss: 1.51559
# Epoch 91/100, Training loss: 1.48038
# Epoch 92/100, Training loss: 1.48110
# Epoch 93/100, Training loss: 1.80746
# Epoch 94/100, Training loss: 1.48686
# Epoch 95/100, Training loss: 1.52881
# Epoch 96/100, Training loss: 1.50185
# Epoch 97/100, Training loss: 1.49421
# Epoch 98/100, Training loss: 1.52266
# Epoch 99/100, Training loss: 1.52791
# Epoch 100/100, Training loss: 1.93275
# [0, 0, 0]
# Epoch 1/100, Training loss: 2.74433
# Epoch 2/100, Training loss: 2.00900
# Epoch 3/100, Training loss: 1.95259
# Epoch 4/100, Training loss: 1.84915
# Epoch 5/100, Training loss: 1.89645
# Epoch 6/100, Training loss: 1.97802
# Epoch 7/100, Training loss: 2.21700
# Epoch 8/100, Training loss: 1.87134
# Epoch 9/100, Training loss: 1.89178
# Epoch 10/100, Training loss: 2.12722
# Epoch 11/100, Training loss: 1.88551
# Epoch 12/100, Training loss: 1.92388
# Epoch 13/100, Training loss: 1.95716
# Epoch 14/100, Training loss: 1.94994
# Epoch 15/100, Training loss: 1.88543
# Epoch 16/100, Training loss: 1.94187
# Epoch 17/100, Training loss: 1.91000
# Epoch 18/100, Training loss: 1.93382
# Epoch 19/100, Training loss: 1.83972
# Epoch 20/100, Training loss: 1.87970
# Epoch 21/100, Training loss: 1.86274
# Epoch 22/100, Training loss: 1.88017
# Epoch 23/100, Training loss: 1.83752
# Epoch 24/100, Training loss: 1.95503
# Epoch 25/100, Training loss: 1.82495
# Epoch 26/100, Training loss: 1.72410
# Epoch 27/100, Training loss: 1.89071
# Epoch 28/100, Training loss: 1.85317
# Epoch 29/100, Training loss: 1.77258
# Epoch 30/100, Training loss: 1.77127
# Epoch 31/100, Training loss: 1.67967
# Epoch 32/100, Training loss: 1.75684
# Epoch 33/100, Training loss: 1.87518
# Epoch 34/100, Training loss: 1.82311
# Epoch 35/100, Training loss: 1.87375
# Epoch 36/100, Training loss: 1.79168
# Epoch 37/100, Training loss: 1.77451
# Epoch 38/100, Training loss: 1.80635
# Epoch 39/100, Training loss: 1.92873
# Epoch 40/100, Training loss: 1.72447
# Epoch 41/100, Training loss: 1.92521
# Epoch 42/100, Training loss: 1.78499
# Epoch 43/100, Training loss: 2.04635
# Epoch 44/100, Training loss: 1.70448
# Epoch 45/100, Training loss: 1.71218
# Epoch 46/100, Training loss: 1.80465
# Epoch 47/100, Training loss: 1.68411
# Epoch 48/100, Training loss: 1.66732
# Epoch 49/100, Training loss: 1.58535
# Epoch 50/100, Training loss: 2.22604
# Epoch 51/100, Training loss: 1.82340
# Epoch 52/100, Training loss: 1.84846
# Epoch 53/100, Training loss: 2.08717
# Epoch 54/100, Training loss: 1.88279
# Epoch 55/100, Training loss: 1.80982
# Epoch 56/100, Training loss: 1.78557
# Epoch 57/100, Training loss: 1.83761
# Epoch 58/100, Training loss: 1.91036
# Epoch 59/100, Training loss: 1.69469
# Epoch 60/100, Training loss: 1.98721
# Epoch 61/100, Training loss: 1.86443
# Epoch 62/100, Training loss: 1.87567
# Epoch 63/100, Training loss: 1.84237
# Epoch 64/100, Training loss: 1.85510
# Epoch 65/100, Training loss: 1.84970
# Epoch 66/100, Training loss: 1.86193
# Epoch 67/100, Training loss: 1.82499
# Epoch 68/100, Training loss: 1.84384
# Epoch 69/100, Training loss: 1.83717
# Epoch 70/100, Training loss: 1.85608
# Epoch 71/100, Training loss: 1.86082
# Epoch 72/100, Training loss: 1.85793
# Epoch 73/100, Training loss: 1.90245
# Epoch 74/100, Training loss: 1.84813
# Epoch 75/100, Training loss: 1.82506
# Epoch 76/100, Training loss: 1.86464
# Epoch 77/100, Training loss: 1.88787
# Epoch 78/100, Training loss: 1.90195
# Epoch 79/100, Training loss: 1.84542
# Epoch 80/100, Training loss: 1.84959
# Epoch 81/100, Training loss: 1.82027
# Epoch 82/100, Training loss: 1.81580
# Epoch 83/100, Training loss: 1.94193
# Epoch 84/100, Training loss: 2.11216
# Epoch 85/100, Training loss: 1.95400
# Epoch 86/100, Training loss: 1.89839
# Epoch 87/100, Training loss: 1.89351
# Epoch 88/100, Training loss: 2.17440
# Epoch 89/100, Training loss: 1.85811
# Epoch 90/100, Training loss: 1.83059
# Epoch 91/100, Training loss: 1.90065
# Epoch 92/100, Training loss: 2.00370
# Epoch 93/100, Training loss: 1.84352
# Epoch 94/100, Training loss: 2.06947
# Epoch 95/100, Training loss: 1.89963
# Epoch 96/100, Training loss: 2.43391
# Epoch 97/100, Training loss: 1.82049
# Epoch 98/100, Training loss: 1.94079
# Epoch 99/100, Training loss: 1.91779
# Epoch 100/100, Training loss: 1.89258
# [0, 0, 0, 0]
# Epoch 1/100, Training loss: 2.71705
# Epoch 2/100, Training loss: 1.92289
# Epoch 3/100, Training loss: 1.90868
# Epoch 4/100, Training loss: 1.87200
# Epoch 5/100, Training loss: 1.92464
# Epoch 6/100, Training loss: 2.27529
# Epoch 7/100, Training loss: 1.87434
# Epoch 8/100, Training loss: 1.74774
# Epoch 9/100, Training loss: 1.67837
# Epoch 10/100, Training loss: 1.73199
# Epoch 11/100, Training loss: 1.68897
# Epoch 12/100, Training loss: 1.46734
# Epoch 13/100, Training loss: 1.40222
# Epoch 14/100, Training loss: 1.44590
# Epoch 15/100, Training loss: 1.54374
# Epoch 16/100, Training loss: 1.73555
# Epoch 17/100, Training loss: 1.36870
# Epoch 18/100, Training loss: 1.31195
# Epoch 19/100, Training loss: 1.29309
# Epoch 20/100, Training loss: 1.21744
# Epoch 21/100, Training loss: 1.23979
# Epoch 22/100, Training loss: 1.18755
# Epoch 23/100, Training loss: 1.39973
# Epoch 24/100, Training loss: 1.15283
# Epoch 25/100, Training loss: 1.08932
# Epoch 26/100, Training loss: 1.15136
# Epoch 27/100, Training loss: 1.23409
# Epoch 28/100, Training loss: 1.17690
# Epoch 29/100, Training loss: 1.15394
# Epoch 30/100, Training loss: 1.34979
# Epoch 31/100, Training loss: 1.32000
# Epoch 32/100, Training loss: 1.25296
# Epoch 33/100, Training loss: 1.53082
# Epoch 34/100, Training loss: 1.45993
# Epoch 35/100, Training loss: 1.26854
# Epoch 36/100, Training loss: 1.21840
# Epoch 37/100, Training loss: 1.58401
# Epoch 38/100, Training loss: 1.59333
# Epoch 39/100, Training loss: 1.38384
# Epoch 40/100, Training loss: 1.53279
# Epoch 41/100, Training loss: 1.43992
# Epoch 42/100, Training loss: 1.25165
# Epoch 43/100, Training loss: 1.14282
# Epoch 44/100, Training loss: 1.13285
# Epoch 45/100, Training loss: 1.14383
# Epoch 46/100, Training loss: 1.35292
# Epoch 47/100, Training loss: 1.12314
# Epoch 48/100, Training loss: 1.11341
# Epoch 49/100, Training loss: 1.13608
# Epoch 50/100, Training loss: 1.58076
# Epoch 51/100, Training loss: 1.55092
# Epoch 52/100, Training loss: 1.07379
# Epoch 53/100, Training loss: 1.07949
# Epoch 54/100, Training loss: 1.21274
# Epoch 55/100, Training loss: 1.10374
# Epoch 56/100, Training loss: 1.22720
# Epoch 57/100, Training loss: 1.12832
# Epoch 58/100, Training loss: 1.16657
# Epoch 59/100, Training loss: 1.09030
# Epoch 60/100, Training loss: 1.16783
# Epoch 61/100, Training loss: 1.13754
# Epoch 62/100, Training loss: 1.37887
# Epoch 63/100, Training loss: 1.24133
# Epoch 64/100, Training loss: 1.68609
# Epoch 65/100, Training loss: 1.91750
# Epoch 66/100, Training loss: 1.55094
# Epoch 67/100, Training loss: 1.47820
# Epoch 68/100, Training loss: 1.35569
# Epoch 69/100, Training loss: 1.45494
# Epoch 70/100, Training loss: 1.49692
# Epoch 71/100, Training loss: 1.45328
# Epoch 72/100, Training loss: 1.56484
# Epoch 73/100, Training loss: 1.32696
# Epoch 74/100, Training loss: 1.38519
# Epoch 75/100, Training loss: 1.46327
# Epoch 76/100, Training loss: 1.64548
# Epoch 77/100, Training loss: 1.42493
# Epoch 78/100, Training loss: 1.37890
# Epoch 79/100, Training loss: 1.37904
# Epoch 80/100, Training loss: 1.40924
# Epoch 81/100, Training loss: 1.34656
# Epoch 82/100, Training loss: 1.29678
# Epoch 83/100, Training loss: 1.52406
# Epoch 84/100, Training loss: 1.57880
# Epoch 85/100, Training loss: 1.94673
# Epoch 86/100, Training loss: 1.44025
# Epoch 87/100, Training loss: 1.78322
# Epoch 88/100, Training loss: 1.49667
# Epoch 89/100, Training loss: 1.36398
# Epoch 90/100, Training loss: 1.35748
# Epoch 91/100, Training loss: 1.44570
# Epoch 92/100, Training loss: 1.54818
# Epoch 93/100, Training loss: 1.42078
# Epoch 94/100, Training loss: 1.47228
# Epoch 95/100, Training loss: 1.42754
# Epoch 96/100, Training loss: 1.33377
# Epoch 97/100, Training loss: 1.32826
# Epoch 98/100, Training loss: 1.37444
# Epoch 99/100, Training loss: 1.53431
# Epoch 100/100, Training loss: 1.41176
# [0, 0, 0, 0, 1]
# Epoch 1/100, Training loss: 4.55877
# Epoch 2/100, Training loss: 1.93921
# Epoch 3/100, Training loss: 1.86745
# Epoch 4/100, Training loss: 1.86117
# Epoch 5/100, Training loss: 1.87403
# Epoch 6/100, Training loss: 1.86613
# Epoch 7/100, Training loss: 1.84505
# Epoch 8/100, Training loss: 1.77787
# Epoch 9/100, Training loss: 1.65259
# Epoch 10/100, Training loss: 1.76070
# Epoch 11/100, Training loss: 1.63642
# Epoch 12/100, Training loss: 1.54794
# Epoch 13/100, Training loss: 1.45760
# Epoch 14/100, Training loss: 1.36174
# Epoch 15/100, Training loss: 1.43632
# Epoch 16/100, Training loss: 1.49665
# Epoch 17/100, Training loss: 1.42591
# Epoch 18/100, Training loss: 1.28141
# Epoch 19/100, Training loss: 1.46853
# Epoch 20/100, Training loss: 1.38939
# Epoch 21/100, Training loss: 1.38857
# Epoch 22/100, Training loss: 1.24384
# Epoch 23/100, Training loss: 1.26348
# Epoch 24/100, Training loss: 1.42851
# Epoch 25/100, Training loss: 1.19053
# Epoch 26/100, Training loss: 1.28227
# Epoch 27/100, Training loss: 1.22168
# Epoch 28/100, Training loss: 1.46538
# Epoch 29/100, Training loss: 1.13912
# Epoch 30/100, Training loss: 1.11894
# Epoch 31/100, Training loss: 1.08149
# Epoch 32/100, Training loss: 1.17822
# Epoch 33/100, Training loss: 1.12636
# Epoch 34/100, Training loss: 1.37014
# Epoch 35/100, Training loss: 1.10466
# Epoch 36/100, Training loss: 1.22489
# Epoch 37/100, Training loss: 1.12449
# Epoch 38/100, Training loss: 1.23274
# Epoch 39/100, Training loss: 1.31205
# Epoch 40/100, Training loss: 1.08010
# Epoch 41/100, Training loss: 1.03404
# Epoch 42/100, Training loss: 1.38518
# Epoch 43/100, Training loss: 1.30161
# Epoch 44/100, Training loss: 1.11161
# Epoch 45/100, Training loss: 1.34749
# Epoch 46/100, Training loss: 1.53245
# Epoch 47/100, Training loss: 1.31454
# Epoch 48/100, Training loss: 1.34370
# Epoch 49/100, Training loss: 1.19966
# Epoch 50/100, Training loss: 1.07940
# Epoch 51/100, Training loss: 1.20382
# Epoch 52/100, Training loss: 1.09945
# Epoch 53/100, Training loss: 1.33373
# Epoch 54/100, Training loss: 1.13133
# Epoch 55/100, Training loss: 1.25609
# Epoch 56/100, Training loss: 1.22455
# Epoch 57/100, Training loss: 1.16753
# Epoch 58/100, Training loss: 1.04594
# Epoch 59/100, Training loss: 1.07710
# Epoch 60/100, Training loss: 1.79689
# Epoch 61/100, Training loss: 1.43970
# Epoch 62/100, Training loss: 1.40513
# Epoch 63/100, Training loss: 1.38124
# Epoch 64/100, Training loss: 1.23657
# Epoch 65/100, Training loss: 1.29906
# Epoch 66/100, Training loss: 1.22883
# Epoch 67/100, Training loss: 1.17793
# Epoch 68/100, Training loss: 1.12417
# Epoch 69/100, Training loss: 1.27751
# Epoch 70/100, Training loss: 1.28210
# Epoch 71/100, Training loss: 1.09053
# Epoch 72/100, Training loss: 1.18569
# Epoch 73/100, Training loss: 1.22346
# Epoch 74/100, Training loss: 1.22060
# Epoch 75/100, Training loss: 1.30595
# Epoch 76/100, Training loss: 1.35792
# Epoch 77/100, Training loss: 1.14034
# Epoch 78/100, Training loss: 1.11531
# Epoch 79/100, Training loss: 1.15167
# Epoch 80/100, Training loss: 1.15164
# Epoch 81/100, Training loss: 1.19605
# Epoch 82/100, Training loss: 1.05872
# Epoch 83/100, Training loss: 1.18624
# Epoch 84/100, Training loss: 1.15974
# Epoch 85/100, Training loss: 1.10152
# Epoch 86/100, Training loss: 1.14580
# Epoch 87/100, Training loss: 1.23912
# Epoch 88/100, Training loss: 1.16136
# Epoch 89/100, Training loss: 1.32156
# Epoch 90/100, Training loss: 1.34322
# Epoch 91/100, Training loss: 1.12242
# Epoch 92/100, Training loss: 1.29862
# Epoch 93/100, Training loss: 1.31325
# Epoch 94/100, Training loss: 1.27973
# Epoch 95/100, Training loss: 1.12242
# Epoch 96/100, Training loss: 1.16426
# Epoch 97/100, Training loss: 1.22741
# Epoch 98/100, Training loss: 1.08841
# Epoch 99/100, Training loss: 1.10106
# Epoch 100/100, Training loss: 1.00724
# [0, 0, 0, 0, 1, 1]
# Epoch 1/100, Training loss: 3.69402
# Epoch 2/100, Training loss: 2.11964
# Epoch 3/100, Training loss: 1.94911
# Epoch 4/100, Training loss: 1.92497
# Epoch 5/100, Training loss: 1.78384
# Epoch 6/100, Training loss: 1.68624
# Epoch 7/100, Training loss: 1.75134
# Epoch 8/100, Training loss: 1.67658
# Epoch 9/100, Training loss: 1.66357
# Epoch 10/100, Training loss: 1.94117
# Epoch 11/100, Training loss: 1.65064
# Epoch 12/100, Training loss: 1.64187
# Epoch 13/100, Training loss: 1.50831
# Epoch 14/100, Training loss: 1.47673
# Epoch 15/100, Training loss: 1.56155
# Epoch 16/100, Training loss: 1.48367
# Epoch 17/100, Training loss: 1.66717
# Epoch 18/100, Training loss: 1.59952
# Epoch 19/100, Training loss: 1.44899
# Epoch 20/100, Training loss: 1.41185
# Epoch 21/100, Training loss: 1.45809
# Epoch 22/100, Training loss: 1.59978
# Epoch 23/100, Training loss: 1.56573
# Epoch 24/100, Training loss: 1.53726
# Epoch 25/100, Training loss: 1.49728
# Epoch 26/100, Training loss: 1.37777
# Epoch 27/100, Training loss: 1.43899
# Epoch 28/100, Training loss: 1.56454
# Epoch 29/100, Training loss: 1.58682
# Epoch 30/100, Training loss: 1.46187
# Epoch 31/100, Training loss: 1.78446
# Epoch 32/100, Training loss: 1.39645
# Epoch 33/100, Training loss: 1.43670
# Epoch 34/100, Training loss: 1.48948
# Epoch 35/100, Training loss: 1.38243
# Epoch 36/100, Training loss: 1.34840
# Epoch 37/100, Training loss: 1.44267
# Epoch 38/100, Training loss: 1.58134
# Epoch 39/100, Training loss: 1.44576
# Epoch 40/100, Training loss: 1.45004
# Epoch 41/100, Training loss: 1.72277
# Epoch 42/100, Training loss: 1.61952
# Epoch 43/100, Training loss: 1.37928
# Epoch 44/100, Training loss: 1.37894
# Epoch 45/100, Training loss: 1.31845
# Epoch 46/100, Training loss: 1.97344
# Epoch 47/100, Training loss: 1.34243
# Epoch 48/100, Training loss: 1.39160
# Epoch 49/100, Training loss: 1.38059
# Epoch 50/100, Training loss: 1.49246
# Epoch 51/100, Training loss: 1.59284
# Epoch 52/100, Training loss: 1.51054
# Epoch 53/100, Training loss: 1.37466
# Epoch 54/100, Training loss: 1.34138
# Epoch 55/100, Training loss: 1.28110
# Epoch 56/100, Training loss: 1.38519
# Epoch 57/100, Training loss: 1.30278
# Epoch 58/100, Training loss: 1.30622
# Epoch 59/100, Training loss: 1.39523
# Epoch 60/100, Training loss: 1.41880
# Epoch 61/100, Training loss: 1.50346
# Epoch 62/100, Training loss: 1.32193
# Epoch 63/100, Training loss: 1.34190
# Epoch 64/100, Training loss: 1.27134
# Epoch 65/100, Training loss: 1.24853
# Epoch 66/100, Training loss: 1.38133
# Epoch 67/100, Training loss: 1.43972
# Epoch 68/100, Training loss: 1.31771
# Epoch 69/100, Training loss: 1.36435
# Epoch 70/100, Training loss: 1.31932
# Epoch 71/100, Training loss: 1.28062
# Epoch 72/100, Training loss: 1.40551
# Epoch 73/100, Training loss: 1.36596
# Epoch 74/100, Training loss: 1.33868
# Epoch 75/100, Training loss: 1.47917
# Epoch 76/100, Training loss: 1.30128
# Epoch 77/100, Training loss: 1.34431
# Epoch 78/100, Training loss: 1.27452
# Epoch 79/100, Training loss: 1.22622
# Epoch 80/100, Training loss: 1.35124
# Epoch 81/100, Training loss: 1.34502
# Epoch 82/100, Training loss: 1.47724
# Epoch 83/100, Training loss: 1.84197
# Epoch 84/100, Training loss: 1.83538
# Epoch 85/100, Training loss: 1.69461
# Epoch 86/100, Training loss: 1.73465
# Epoch 87/100, Training loss: 1.87544
# Epoch 88/100, Training loss: 1.63667
# Epoch 89/100, Training loss: 1.58139
# Epoch 90/100, Training loss: 1.53227
# Epoch 91/100, Training loss: 1.56995
# Epoch 92/100, Training loss: 1.63127
# Epoch 93/100, Training loss: 1.71851
# Epoch 94/100, Training loss: 1.73676
# Epoch 95/100, Training loss: 1.65536
# Epoch 96/100, Training loss: 1.64099
# Epoch 97/100, Training loss: 1.67530
# Epoch 98/100, Training loss: 1.65435
# Epoch 99/100, Training loss: 1.60131
# Epoch 100/100, Training loss: 1.57208
# [0, 0, 0, 0, 1, 1, 1]
# Epoch 1/100, Training loss: 2.85963
# Epoch 2/100, Training loss: 2.00709
# Epoch 3/100, Training loss: 1.87171
# Epoch 4/100, Training loss: 1.86537
# Epoch 5/100, Training loss: 1.99155
# Epoch 6/100, Training loss: 1.90887
# Epoch 7/100, Training loss: 1.92961
# Epoch 8/100, Training loss: 1.99102
# Epoch 9/100, Training loss: 1.85149
# Epoch 10/100, Training loss: 1.87840
# Epoch 11/100, Training loss: 1.88663
# Epoch 12/100, Training loss: 1.76202
# Epoch 13/100, Training loss: 1.77708
# Epoch 14/100, Training loss: 1.72964
# Epoch 15/100, Training loss: 1.62633
# Epoch 16/100, Training loss: 1.95687
# Epoch 17/100, Training loss: 1.88772
# Epoch 18/100, Training loss: 1.88624
# Epoch 19/100, Training loss: 1.86522
# Epoch 20/100, Training loss: 1.88766
# Epoch 21/100, Training loss: 1.80951
# Epoch 22/100, Training loss: 1.78273
# Epoch 23/100, Training loss: 1.77832
# Epoch 24/100, Training loss: 1.88123
# Epoch 25/100, Training loss: 1.80814
# Epoch 26/100, Training loss: 1.92962
# Epoch 27/100, Training loss: 1.89741
# Epoch 28/100, Training loss: 1.83016
# Epoch 29/100, Training loss: 1.85490
# Epoch 30/100, Training loss: 1.78119
# Epoch 31/100, Training loss: 1.90954
# Epoch 32/100, Training loss: 1.88840
# Epoch 33/100, Training loss: 1.89340
# Epoch 34/100, Training loss: 1.91986
# Epoch 35/100, Training loss: 1.85672
# Epoch 36/100, Training loss: 1.84334
# Epoch 37/100, Training loss: 1.83591
# Epoch 38/100, Training loss: 1.99619
# Epoch 39/100, Training loss: 1.86681
# Epoch 40/100, Training loss: 1.94095
# Epoch 41/100, Training loss: 1.88745
# Epoch 42/100, Training loss: 1.92314
# Epoch 43/100, Training loss: 1.77739
# Epoch 44/100, Training loss: 1.80834
# Epoch 45/100, Training loss: 2.01447
# Epoch 46/100, Training loss: 1.94505
# Epoch 47/100, Training loss: 1.86900
# Epoch 48/100, Training loss: 2.12906
# Epoch 49/100, Training loss: 1.88543
# Epoch 50/100, Training loss: 1.87875
# Epoch 51/100, Training loss: 1.84367
# Epoch 52/100, Training loss: 1.85889
# Epoch 53/100, Training loss: 1.92502
# Epoch 54/100, Training loss: 1.89511
# Epoch 55/100, Training loss: 1.86929
# Epoch 56/100, Training loss: 1.93305
# Epoch 57/100, Training loss: 1.86581
# Epoch 58/100, Training loss: 1.86394
# Epoch 59/100, Training loss: 1.94497
# Epoch 60/100, Training loss: 1.88650
# Epoch 61/100, Training loss: 1.88891
# Epoch 62/100, Training loss: 1.87225
# Epoch 63/100, Training loss: 1.84977
# Epoch 64/100, Training loss: 1.90849
# Epoch 65/100, Training loss: 1.89521
# Epoch 66/100, Training loss: 2.04751
# Epoch 67/100, Training loss: 1.86363
# Epoch 68/100, Training loss: 1.86112
# Epoch 69/100, Training loss: 1.88991
# Epoch 70/100, Training loss: 1.86685
# Epoch 71/100, Training loss: 1.86745
# Epoch 72/100, Training loss: 1.85293
# Epoch 73/100, Training loss: 1.82100
# Epoch 74/100, Training loss: 1.86643
# Epoch 75/100, Training loss: 1.83824
# Epoch 76/100, Training loss: 1.82147
# Epoch 77/100, Training loss: 1.96593
# Epoch 78/100, Training loss: 1.81849
# Epoch 79/100, Training loss: 1.96387
# Epoch 80/100, Training loss: 1.85105
# Epoch 81/100, Training loss: 1.87150
# Epoch 82/100, Training loss: 2.25952
# Epoch 83/100, Training loss: 2.02902
# Epoch 84/100, Training loss: 1.90216
# Epoch 85/100, Training loss: 1.87174
# Epoch 86/100, Training loss: 1.86789
# Epoch 87/100, Training loss: 1.81047
# Epoch 88/100, Training loss: 2.03710
# Epoch 89/100, Training loss: 1.86359
# Epoch 90/100, Training loss: 1.86716
# Epoch 91/100, Training loss: 1.84908
# Epoch 92/100, Training loss: 1.88105
# Epoch 93/100, Training loss: 1.88431
# Epoch 94/100, Training loss: 1.91431
# Epoch 95/100, Training loss: 1.86032
# Epoch 96/100, Training loss: 1.85759
# Epoch 97/100, Training loss: 1.84491
# Epoch 98/100, Training loss: 1.88905
# Epoch 99/100, Training loss: 1.86349
# Epoch 100/100, Training loss: 1.84745
# [0, 0, 0, 0, 1, 1, 1, 0]
# Epoch 1/100, Training loss: 2.88631
# Epoch 2/100, Training loss: 1.96861
# Epoch 3/100, Training loss: 1.90922
# Epoch 4/100, Training loss: 1.88465
# Epoch 5/100, Training loss: 1.78238
# Epoch 6/100, Training loss: 1.98330
# Epoch 7/100, Training loss: 1.68529
# Epoch 8/100, Training loss: 1.67129
# Epoch 9/100, Training loss: 1.92214
# Epoch 10/100, Training loss: 1.73301
# Epoch 11/100, Training loss: 1.55524
# Epoch 12/100, Training loss: 1.51135
# Epoch 13/100, Training loss: 1.73888
# Epoch 14/100, Training loss: 1.57527
# Epoch 15/100, Training loss: 1.57378
# Epoch 16/100, Training loss: 1.70432
# Epoch 17/100, Training loss: 1.39295
# Epoch 18/100, Training loss: 1.42536
# Epoch 19/100, Training loss: 1.51217
# Epoch 20/100, Training loss: 1.68932
# Epoch 21/100, Training loss: 1.41149
# Epoch 22/100, Training loss: 1.46766
# Epoch 23/100, Training loss: 1.94207
# Epoch 24/100, Training loss: 1.51747
# Epoch 25/100, Training loss: 1.42214
# Epoch 26/100, Training loss: 1.41839
# Epoch 27/100, Training loss: 1.36743
# Epoch 28/100, Training loss: 1.31638
# Epoch 29/100, Training loss: 1.35223
# Epoch 30/100, Training loss: 1.31438
# Epoch 31/100, Training loss: 1.28121
# Epoch 32/100, Training loss: 1.28845
# Epoch 33/100, Training loss: 1.24320
# Epoch 34/100, Training loss: 1.30699
# Epoch 35/100, Training loss: 1.61204
# Epoch 36/100, Training loss: 1.26657
# Epoch 37/100, Training loss: 1.16610
# Epoch 38/100, Training loss: 1.20366
# Epoch 39/100, Training loss: 1.28374
# Epoch 40/100, Training loss: 1.18437
# Epoch 41/100, Training loss: 1.65450
# Epoch 42/100, Training loss: 1.52263
# Epoch 43/100, Training loss: 1.34386
# Epoch 44/100, Training loss: 1.33836
# Epoch 45/100, Training loss: 1.26163
# Epoch 46/100, Training loss: 1.43928
# Epoch 47/100, Training loss: 1.27309
# Epoch 48/100, Training loss: 1.39891
# Epoch 49/100, Training loss: 1.43789
# Epoch 50/100, Training loss: 1.30379
# Epoch 51/100, Training loss: 1.28793
# Epoch 52/100, Training loss: 1.17247
# Epoch 53/100, Training loss: 1.33436
# Epoch 54/100, Training loss: 1.22380
# Epoch 55/100, Training loss: 1.41239
# Epoch 56/100, Training loss: 1.31529
# Epoch 57/100, Training loss: 1.33670
# Epoch 58/100, Training loss: 1.27277
# Epoch 59/100, Training loss: 1.39207
# Epoch 60/100, Training loss: 1.28317
# Epoch 61/100, Training loss: 1.27967
# Epoch 62/100, Training loss: 1.26098
# Epoch 63/100, Training loss: 1.20585
# Epoch 64/100, Training loss: 1.36660
# Epoch 65/100, Training loss: 1.49550
# Epoch 66/100, Training loss: 1.34514
# Epoch 67/100, Training loss: 1.33631
# Epoch 68/100, Training loss: 1.24695
# Epoch 69/100, Training loss: 1.30878
# Epoch 70/100, Training loss: 1.26195
# Epoch 71/100, Training loss: 1.26870
# Epoch 72/100, Training loss: 1.18157
# Epoch 73/100, Training loss: 1.20451
# Epoch 74/100, Training loss: 1.23052
# Epoch 75/100, Training loss: 1.23214
# Epoch 76/100, Training loss: 1.33317
# Epoch 77/100, Training loss: 1.27121
# Epoch 78/100, Training loss: 1.16665
# Epoch 79/100, Training loss: 1.26948
# Epoch 80/100, Training loss: 1.34750
# Epoch 81/100, Training loss: 1.27231
# Epoch 82/100, Training loss: 1.35607
# Epoch 83/100, Training loss: 1.19379
# Epoch 84/100, Training loss: 1.30016
# Epoch 85/100, Training loss: 1.16225
# Epoch 86/100, Training loss: 1.59173
# Epoch 87/100, Training loss: 1.42288
# Epoch 88/100, Training loss: 1.39862
# Epoch 89/100, Training loss: 1.26439
# Epoch 90/100, Training loss: 1.50273
# Epoch 91/100, Training loss: 1.38151
# Epoch 92/100, Training loss: 1.45287
# Epoch 93/100, Training loss: 1.39862
# Epoch 94/100, Training loss: 1.28759
# Epoch 95/100, Training loss: 1.30399
# Epoch 96/100, Training loss: 1.43115
# Epoch 97/100, Training loss: 1.36598
# Epoch 98/100, Training loss: 1.26618
# Epoch 99/100, Training loss: 1.37303
# Epoch 100/100, Training loss: 1.32616
# [0, 0, 0, 0, 1, 1, 1, 0, 0]
# Epoch 1/100, Training loss: 3.65190
# Epoch 2/100, Training loss: 1.97856
# Epoch 3/100, Training loss: 1.84602
# Epoch 4/100, Training loss: 1.89246
# Epoch 5/100, Training loss: 1.88090
# Epoch 6/100, Training loss: 1.88273
# Epoch 7/100, Training loss: 1.93810
# Epoch 8/100, Training loss: 1.90200
# Epoch 9/100, Training loss: 1.81639
# Epoch 10/100, Training loss: 1.89862
# Epoch 11/100, Training loss: 1.89897
# Epoch 12/100, Training loss: 1.71951
# Epoch 13/100, Training loss: 1.95685
# Epoch 14/100, Training loss: 1.87539
# Epoch 15/100, Training loss: 1.78843
# Epoch 16/100, Training loss: 1.77666
# Epoch 17/100, Training loss: 1.77951
# Epoch 18/100, Training loss: 1.95980
# Epoch 19/100, Training loss: 2.03632
# Epoch 20/100, Training loss: 1.70868
# Epoch 21/100, Training loss: 1.77574
# Epoch 22/100, Training loss: 1.73280
# Epoch 23/100, Training loss: 1.92348
# Epoch 24/100, Training loss: 1.84242
# Epoch 25/100, Training loss: 1.81331
# Epoch 26/100, Training loss: 1.67181
# Epoch 27/100, Training loss: 1.90114
# Epoch 28/100, Training loss: 1.67077
# Epoch 29/100, Training loss: 1.70139
# Epoch 30/100, Training loss: 1.69984
# Epoch 31/100, Training loss: 1.60200
# Epoch 32/100, Training loss: 1.74346
# Epoch 33/100, Training loss: 1.58347
# Epoch 34/100, Training loss: 1.60745
# Epoch 35/100, Training loss: 1.67072
# Epoch 36/100, Training loss: 1.58101
# Epoch 37/100, Training loss: 1.70690
# Epoch 38/100, Training loss: 1.52241
# Epoch 39/100, Training loss: 1.49365
# Epoch 40/100, Training loss: 1.53235
# Epoch 41/100, Training loss: 1.71758
# Epoch 42/100, Training loss: 1.74008
# Epoch 43/100, Training loss: 1.61828
# Epoch 44/100, Training loss: 1.56771
# Epoch 45/100, Training loss: 1.44229
# Epoch 46/100, Training loss: 1.46704
# Epoch 47/100, Training loss: 1.48801
# Epoch 48/100, Training loss: 1.43138
# Epoch 49/100, Training loss: 1.57743
# Epoch 50/100, Training loss: 1.54449
# Epoch 51/100, Training loss: 1.49813
# Epoch 52/100, Training loss: 1.62741
# Epoch 53/100, Training loss: 1.55478
# Epoch 54/100, Training loss: 1.48112
# Epoch 55/100, Training loss: 1.52853
# Epoch 56/100, Training loss: 1.51255
# Epoch 57/100, Training loss: 1.49760
# Epoch 58/100, Training loss: 1.50797
# Epoch 59/100, Training loss: 1.51808
# Epoch 60/100, Training loss: 1.67740
# Epoch 61/100, Training loss: 1.51837
# Epoch 62/100, Training loss: 1.52872
# Epoch 63/100, Training loss: 1.49488
# Epoch 64/100, Training loss: 1.55233
# Epoch 65/100, Training loss: 1.53409
# Epoch 66/100, Training loss: 1.69412
# Epoch 67/100, Training loss: 1.63036
# Epoch 68/100, Training loss: 1.48269
# Epoch 69/100, Training loss: 1.54943
# Epoch 70/100, Training loss: 1.45379
# Epoch 71/100, Training loss: 1.60647
# Epoch 72/100, Training loss: 1.62327
# Epoch 73/100, Training loss: 1.49137
# Epoch 74/100, Training loss: 1.48564
# Epoch 75/100, Training loss: 1.40876
# Epoch 76/100, Training loss: 1.53818
# Epoch 77/100, Training loss: 1.59823
# Epoch 78/100, Training loss: 1.65861
# Epoch 79/100, Training loss: 1.59615
# Epoch 80/100, Training loss: 1.62734
# Epoch 81/100, Training loss: 1.73055
# Epoch 82/100, Training loss: 1.54714
# Epoch 83/100, Training loss: 1.51373
# Epoch 84/100, Training loss: 1.45558
# Epoch 85/100, Training loss: 1.54741
# Epoch 86/100, Training loss: 1.49971
# Epoch 87/100, Training loss: 1.55627
# Epoch 88/100, Training loss: 1.54246
# Epoch 89/100, Training loss: 1.50061
# Epoch 90/100, Training loss: 1.45443
# Epoch 91/100, Training loss: 1.66911
# Epoch 92/100, Training loss: 1.52030
# Epoch 93/100, Training loss: 1.49399
# Epoch 94/100, Training loss: 1.56254
# Epoch 95/100, Training loss: 1.58737
# Epoch 96/100, Training loss: 1.64045
# Epoch 97/100, Training loss: 1.61956
# Epoch 98/100, Training loss: 1.49051
# Epoch 99/100, Training loss: 1.55633
# Epoch 100/100, Training loss: 1.43433
# [0, 0, 0, 0, 1, 1, 1, 0, 0, 1]
# Epoch 1/100, Training loss: 3.83228
# Epoch 2/100, Training loss: 2.01741
# Epoch 3/100, Training loss: 1.92155
# Epoch 4/100, Training loss: 1.91186
# Epoch 5/100, Training loss: 1.86269
# Epoch 6/100, Training loss: 2.11018
# Epoch 7/100, Training loss: 2.20763
# Epoch 8/100, Training loss: 1.84520
# Epoch 9/100, Training loss: 1.73787
# Epoch 10/100, Training loss: 1.85109
# Epoch 11/100, Training loss: 1.80919
# Epoch 12/100, Training loss: 1.80330
# Epoch 13/100, Training loss: 1.67007
# Epoch 14/100, Training loss: 1.76916
# Epoch 15/100, Training loss: 1.77529
# Epoch 16/100, Training loss: 1.53798
# Epoch 17/100, Training loss: 1.50338
# Epoch 18/100, Training loss: 1.43374
# Epoch 19/100, Training loss: 1.47182
# Epoch 20/100, Training loss: 1.30621
# Epoch 21/100, Training loss: 1.26112
# Epoch 22/100, Training loss: 1.35779
# Epoch 23/100, Training loss: 1.28422
# Epoch 24/100, Training loss: 1.50552
# Epoch 25/100, Training loss: 1.20007
# Epoch 26/100, Training loss: 1.22262
# Epoch 27/100, Training loss: 1.69202
# Epoch 28/100, Training loss: 1.87202
# Epoch 29/100, Training loss: 1.71204
# Epoch 30/100, Training loss: 1.44572
# Epoch 31/100, Training loss: 1.31271
# Epoch 32/100, Training loss: 1.29123
# Epoch 33/100, Training loss: 1.66065
# Epoch 34/100, Training loss: 1.61178
# Epoch 35/100, Training loss: 1.46617
# Epoch 36/100, Training loss: 1.49902
# Epoch 37/100, Training loss: 1.59025
# Epoch 38/100, Training loss: 1.61427
# Epoch 39/100, Training loss: 1.83351
# Epoch 40/100, Training loss: 1.75732
# Epoch 41/100, Training loss: 1.73360
# Epoch 42/100, Training loss: 1.66999
# Epoch 43/100, Training loss: 1.69062
# Epoch 44/100, Training loss: 2.03023
# Epoch 45/100, Training loss: 1.94565
# Epoch 46/100, Training loss: 1.88996
# Epoch 47/100, Training loss: 1.88753
# Epoch 48/100, Training loss: 1.87634
# Epoch 49/100, Training loss: 1.86177
# Epoch 50/100, Training loss: 1.81393
# Epoch 51/100, Training loss: 1.96752
# Epoch 52/100, Training loss: 1.88755
# Epoch 53/100, Training loss: 1.90384
# Epoch 54/100, Training loss: 1.85250
# Epoch 55/100, Training loss: 1.79394
# Epoch 56/100, Training loss: 2.24734
# Epoch 57/100, Training loss: 1.80943
# Epoch 58/100, Training loss: 1.86341
# Epoch 59/100, Training loss: 1.83958
# Epoch 60/100, Training loss: 1.85154
# Epoch 61/100, Training loss: 1.90014
# Epoch 62/100, Training loss: 1.85122
# Epoch 63/100, Training loss: 1.83698
# Epoch 64/100, Training loss: 1.89595
# Epoch 65/100, Training loss: 1.85642
# Epoch 66/100, Training loss: 1.83065
# Epoch 67/100, Training loss: 1.81629
# Epoch 68/100, Training loss: 1.83892
# Epoch 69/100, Training loss: 1.84252
# Epoch 70/100, Training loss: 1.77869
# Epoch 71/100, Training loss: 1.84078
# Epoch 72/100, Training loss: 1.93147
# Epoch 73/100, Training loss: 1.82992
# Epoch 74/100, Training loss: 1.85585
# Epoch 75/100, Training loss: 1.90557
# Epoch 76/100, Training loss: 1.96336
# Epoch 77/100, Training loss: 1.85524
# Epoch 78/100, Training loss: 1.79357
# Epoch 79/100, Training loss: 1.81829
# Epoch 80/100, Training loss: 1.81806
# Epoch 81/100, Training loss: 2.00837
# Epoch 82/100, Training loss: 1.87802
# Epoch 83/100, Training loss: 1.87296
# Epoch 84/100, Training loss: 1.84846
# Epoch 85/100, Training loss: 1.88694
# Epoch 86/100, Training loss: 1.88668
# Epoch 87/100, Training loss: 1.88384
# Epoch 88/100, Training loss: 1.85817
# Epoch 89/100, Training loss: 1.90747
# Epoch 90/100, Training loss: 1.84384
# Epoch 91/100, Training loss: 1.89052
# Epoch 92/100, Training loss: 1.86280
# Epoch 93/100, Training loss: 1.84341
# Epoch 94/100, Training loss: 1.87141
# Epoch 95/100, Training loss: 1.84193
# Epoch 96/100, Training loss: 1.91912
# Epoch 97/100, Training loss: 1.84376
# Epoch 98/100, Training loss: 1.85708
# Epoch 99/100, Training loss: 1.82325
# Epoch 100/100, Training loss: 1.82893
# [0, 0, 0, 0, 1, 1, 1, 0, 0, 1, 0]
# Epoch 1/100, Training loss: 2.91589
# Epoch 2/100, Training loss: 2.07230
# Epoch 3/100, Training loss: 1.86225
# Epoch 4/100, Training loss: 1.96730
# Epoch 5/100, Training loss: 1.86297
# Epoch 6/100, Training loss: 1.86424
# Epoch 7/100, Training loss: 1.69043
# Epoch 8/100, Training loss: 1.75885
# Epoch 9/100, Training loss: 1.70979
# Epoch 10/100, Training loss: 1.73695
# Epoch 11/100, Training loss: 1.57101
# Epoch 12/100, Training loss: 1.77125
# Epoch 13/100, Training loss: 1.65493
# Epoch 14/100, Training loss: 1.58954
# Epoch 15/100, Training loss: 1.41004
# Epoch 16/100, Training loss: 1.47879
# Epoch 17/100, Training loss: 1.37637
# Epoch 18/100, Training loss: 1.31766
# Epoch 19/100, Training loss: 1.34862
# Epoch 20/100, Training loss: 1.37201
# Epoch 21/100, Training loss: 1.23225
# Epoch 22/100, Training loss: 1.22000
# Epoch 23/100, Training loss: 1.28141
# Epoch 24/100, Training loss: 1.33672
# Epoch 25/100, Training loss: 2.04440
# Epoch 26/100, Training loss: 1.43472
# Epoch 27/100, Training loss: 1.44701
# Epoch 28/100, Training loss: 1.34827
# Epoch 29/100, Training loss: 1.65048
# Epoch 30/100, Training loss: 1.84816
# Epoch 31/100, Training loss: 1.50347
# Epoch 32/100, Training loss: 1.45816
# Epoch 33/100, Training loss: 1.44316
# Epoch 34/100, Training loss: 1.47410
# Epoch 35/100, Training loss: 1.32484
# Epoch 36/100, Training loss: 1.39922
# Epoch 37/100, Training loss: 1.44205
# Epoch 38/100, Training loss: 1.51774
# Epoch 39/100, Training loss: 1.37103
# Epoch 40/100, Training loss: 1.34424
# Epoch 41/100, Training loss: 1.37578
# Epoch 42/100, Training loss: 1.28878
# Epoch 43/100, Training loss: 1.23211
# Epoch 44/100, Training loss: 1.28242
# Epoch 45/100, Training loss: 1.36711
# Epoch 46/100, Training loss: 1.31387
# Epoch 47/100, Training loss: 1.39761
# Epoch 48/100, Training loss: 1.49277
# Epoch 49/100, Training loss: 1.53071
# Epoch 50/100, Training loss: 1.48001
# Epoch 51/100, Training loss: 1.35393
# Epoch 52/100, Training loss: 1.31243
# Epoch 53/100, Training loss: 1.41842
# Epoch 54/100, Training loss: 1.63653
# Epoch 55/100, Training loss: 1.34851
# Epoch 56/100, Training loss: 1.31456
# Epoch 57/100, Training loss: 1.27257
# Epoch 58/100, Training loss: 1.32621
# Epoch 59/100, Training loss: 1.25516
# Epoch 60/100, Training loss: 1.24797
# Epoch 61/100, Training loss: 1.35916
# Epoch 62/100, Training loss: 1.60191
# Epoch 63/100, Training loss: 1.41693
# Epoch 64/100, Training loss: 1.35120
# Epoch 65/100, Training loss: 1.25353
# Epoch 66/100, Training loss: 1.18410
# Epoch 67/100, Training loss: 1.53829
# Epoch 68/100, Training loss: 1.52712
# Epoch 69/100, Training loss: 1.53021
# Epoch 70/100, Training loss: 1.56981
# Epoch 71/100, Training loss: 1.32849
# Epoch 72/100, Training loss: 1.30470
# Epoch 73/100, Training loss: 1.32003
# Epoch 74/100, Training loss: 1.35807
# Epoch 75/100, Training loss: 1.27274
# Epoch 76/100, Training loss: 1.50094
# Epoch 77/100, Training loss: 1.27307
# Epoch 78/100, Training loss: 1.45344
# Epoch 79/100, Training loss: 1.24900
# Epoch 80/100, Training loss: 1.21586
# Epoch 81/100, Training loss: 1.47511
# Epoch 82/100, Training loss: 1.19640
# Epoch 83/100, Training loss: 1.20983
# Epoch 84/100, Training loss: 1.32333
# Epoch 85/100, Training loss: 1.30496
# Epoch 86/100, Training loss: 1.37132
# Epoch 87/100, Training loss: 1.40956
# Epoch 88/100, Training loss: 1.43182
# Epoch 89/100, Training loss: 1.65542
# Epoch 90/100, Training loss: 1.26489
# Epoch 91/100, Training loss: 1.32471
# Epoch 92/100, Training loss: 1.25947
# Epoch 93/100, Training loss: 1.24254
# Epoch 94/100, Training loss: 1.25214
# Epoch 95/100, Training loss: 1.36026
# Epoch 96/100, Training loss: 1.32940
# Epoch 97/100, Training loss: 1.35472
# Epoch 98/100, Training loss: 1.28467
# Epoch 99/100, Training loss: 1.28203
# Epoch 100/100, Training loss: 1.21677
# [0, 0, 0, 0, 1, 1, 1, 0, 0, 1, 0, 0]
# Epoch 1/100, Training loss: 4.74195
# Epoch 2/100, Training loss: 2.02717
# Epoch 3/100, Training loss: 1.89526
# Epoch 4/100, Training loss: 1.95016
# Epoch 5/100, Training loss: 1.92701
# Epoch 6/100, Training loss: 1.90582
# Epoch 7/100, Training loss: 1.83047
# Epoch 8/100, Training loss: 1.92736
# Epoch 9/100, Training loss: 1.99562
# Epoch 10/100, Training loss: 1.84836
# Epoch 11/100, Training loss: 1.81941
# Epoch 12/100, Training loss: 1.74813
# Epoch 13/100, Training loss: 1.82190
# Epoch 14/100, Training loss: 1.82190
# Epoch 15/100, Training loss: 1.89115
# Epoch 16/100, Training loss: 1.94907
# Epoch 17/100, Training loss: 1.80804
# Epoch 18/100, Training loss: 1.75636
# Epoch 19/100, Training loss: 1.76910
# Epoch 20/100, Training loss: 1.77968
# Epoch 21/100, Training loss: 1.73090
# Epoch 22/100, Training loss: 1.71748
# Epoch 23/100, Training loss: 1.66765
# Epoch 24/100, Training loss: 1.72842
# Epoch 25/100, Training loss: 1.88115
# Epoch 26/100, Training loss: 1.78335
# Epoch 27/100, Training loss: 1.81965
# Epoch 28/100, Training loss: 1.76727
# Epoch 29/100, Training loss: 1.73194
# Epoch 30/100, Training loss: 1.80851
# Epoch 31/100, Training loss: 1.84894
# Epoch 32/100, Training loss: 1.80135
# Epoch 33/100, Training loss: 1.75491
# Epoch 34/100, Training loss: 1.83025
# Epoch 35/100, Training loss: 1.85441
# Epoch 36/100, Training loss: 1.92367
# Epoch 37/100, Training loss: 1.90589
# Epoch 38/100, Training loss: 1.93676
# Epoch 39/100, Training loss: 1.99908
# Epoch 40/100, Training loss: 1.96250
# Epoch 41/100, Training loss: 1.87603
# Epoch 42/100, Training loss: 2.02526
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-fd56270c5462> in <module>
#      78         for xb, yb in trainloader:
#      79             # clear gradients - otherwise they are stored
# ---> 80             optimizer.zero_grad()
#      81             # Training pass
#      82             output = model.forward(xb)
#
# ~/.conda/envs/envs_dl/lib/python3.7/site-packages/torch/optim/optimizer.py in zero_grad(self)
#     163                 if p.grad is not None:
#     164                     p.grad.detach_()
# --> 165                     p.grad.zero_()
#     166
#     167     def step(self, closure):
#
# KeyboardInterrupt:

# %% [markdown]
# # **Determine LOOCV Mean Error**

# %%
percent_correct = sum(results_ls)
percent_correct = percent_correct/len(mcTrain_y)*100
percent_incorrect = 100 - percent_correct
percent_incorrect = round(percent_incorrect, 1)
#print('Percent Error', round(percent_incorrect, 1))

# %% [markdown]
# # **Incorrect Predictions**

# %%
## Remove the correct elements from the ls to faciliate transforming this list into a dataframe
# First, concatenate all incorrect list elements and format into dataframe
incorrect_res = np.concatenate(incorrect_ls)
incorrect_res = pd.DataFrame(incorrect_res)
incorrect_res.columns = ['diagnosis']
incorrect_res = incorrect_res[incorrect_res.diagnosis != 999] # 999 are the results that were correct - we remove these

# Count number of incorrect predictions by diagnosis
incorrect_pred = incorrect_res.groupby(['diagnosis']).size()
incorrect_pred = pd.DataFrame(incorrect_pred)
incorrect_pred.columns = ['Count']

# Convert the index to the first column and change the numebr to categorical variables
incorrect_pred.reset_index(level=0, inplace=True)
incorrect_pred['diagnosis'] = incorrect_pred['diagnosis'].map({0: 'HEA', 1: 'CRC', 2: 'ESCA', 3: 'HCC', 4: 'STAD', 5:'GBM', 6:'BRCA'})

# Add a column with the number of cases in each class
mcTrain_y['diagnosis'] = mcTrain_y['diagnosis'].map({0: 'HEA', 1: 'CRC', 2: 'ESCA', 3: 'HCC', 4: 'STAD', 5:'GBM', 6:'BRCA'})
class_size = mcTrain_y.groupby(['diagnosis']).size()
class_size = pd.DataFrame(class_size)
class_size.columns = ['Sample_n']

# bind class_size to the pred df diagnoses
incorrect_pred = pd.merge(incorrect_pred, class_size, how="left", on="diagnosis") 

# Calculate the percent error for each class
incorrect_pred['Count_Perc_Incorrect'] = incorrect_pred['Count']/incorrect_pred['Sample_n']
incorrect_pred['Count_Perc_Incorrect'] = incorrect_pred['Count_Perc_Incorrect'].multiply(100)

# %% [markdown]
# # **Correct Predictions**

# %%
## Remove the incorrect elements from the ls to faciliate transforming this list into a dataframe
# First, concatenate all incorrect list elements and format into dataframe
correct_res = np.concatenate(correct_ls)
correct_res = pd.DataFrame(correct_res)
correct_res.columns = ['diagnosis']
correct_res = correct_res[correct_res.diagnosis != 999] # 999 are the results that were incorrect - we remove these

# Count number of correct predictions by diagnosis
correct_pred = correct_res.groupby(['diagnosis']).size()
correct_pred = pd.DataFrame(correct_pred)
correct_pred.columns = ['Count']

# Convert the index to the first column and change the numebr to categorical variables
correct_pred.reset_index(level=0, inplace=True)
correct_pred['diagnosis'] = correct_pred['diagnosis'].map({0: 'HEA', 1: 'CRC', 2: 'ESCA', 3: 'HCC', 4: 'STAD', 5:'GBM', 6:'BRCA'})

# Add a column with the number of cases in each class
class_size = mcTrain_y.groupby(['diagnosis']).size()
class_size = pd.DataFrame(class_size)
class_size.columns = ['Sample_n']

# bind class_size to the pred df diagnoses
correct_pred = pd.merge(correct_pred, class_size, how="left", on="diagnosis") 

# Calculate the percent correct for each class
correct_pred['Count_Perc_Correct'] = correct_pred['Count']/correct_pred['Sample_n']
correct_pred['Count_Perc_Correct'] = correct_pred['Count_Perc_Correct'].multiply(100)

# %% [markdown]
# # **Save Predictions**

# %%
# convert float to string in order to save as a txt file
percent_error = '     Percent Error'
percent_error = str(percent_error)
percent_incorrect = str(percent_incorrect)

# save the pre-specified summary of the experiment which includes parameter spe$
summary = summary + percent_error + percent_incorrect

#Feb 21, 2020 Test
print(summary)
print(correct_pred)
