# %% [markdown]
# # **Methylation Biomarkers for Predicting Cancer**
#
# ## **Random Forest for Feature Selection**
#
# **Author:** Meg Hutch
#
# **Date:** March 9, 2020
#
# **Objective:** Use random forest to select genes for features in our deep learning classifier.
#
# **Update**: Could try and choose a classifier maybe based off highest AUC and accuracy

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report, roc_curve, roc_auc_score, accuracy_score, auc, precision_score, recall_score, precision_recall_fscore_support, f1_score, log_loss
from sklearn.metrics import make_scorer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OneVsOneClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import f1_score

# %%
# set working directory for git hub
import os
os.chdir('/home/mrh1996/')
#os.chdir('C:\\Users\\User\\Box Sync/Projects/')
os. getcwd()
# Out:
# '/home/mrh1996'

# %% [markdown]
# **Import the training and testing sets**

# %%
mcTrain_x = pd.read_csv('Multi_Cancer_DL/02_Processed_Data/GI_Datasets/mcTrain_x_gi_Full_70_30.csv')
mcTrain_y = pd.read_csv('Multi_Cancer_DL/02_Processed_Data/GI_Datasets/mcTrain_y_gi_Full_70_30.csv')

mcTest_x = pd.read_csv('Multi_Cancer_DL/02_Processed_Data/GI_Datasets/mcTest_x_gi_Full_70_30.csv')
mcTest_y = pd.read_csv('Multi_Cancer_DL/02_Processed_Data/GI_Datasets/mcTest_y_gi_Full_70_30.csv')

# %% [markdown]
# **Drop Un-neccessary columns**

# %%
mcTrain_x = mcTrain_x.drop(columns=["dilute_library_concentration", "age", "gender", "frag_mean"])
mcTest_x = mcTest_x.drop(columns=["dilute_library_concentration", "age", "gender", "frag_mean"])

# %% [markdown]
# **Convert seq_num id to index**

# %%
mcTrain_x = mcTrain_x.set_index('id')
mcTrain_y = mcTrain_y.set_index('id')

mcTest_x = mcTest_x.set_index('id')
mcTest_y = mcTest_y.set_index('id')

# %% [markdown]
# **Rename datasets**

# %%
X_train = mcTrain_x
y_train = mcTrain_y

X_test = mcTest_x
y_test = mcTest_y

# %% [markdown]
# **One-hot encode y classes**

# %%
from sklearn import preprocessing
y_train_multi = preprocessing.label_binarize(y_train, classes=[0, 1, 2, 3, 4])
y_test_multi = preprocessing.label_binarize(y_test, classes=[0, 1, 2, 3, 4])

# %% [markdown]
# **Convert to arrays**

# %%
# save copy of X_train - this will be used for feature selection down the line
X_train_orig = X_train

# Convert all to arrays
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values 
y_test = y_test.values

# Convert y_train to 1D
y_train = y_train.ravel()

# %% [markdown]
# # **Random Forest**
#
# The hyperparameter tuning function was adapted from Garrett's modeling lecture:
#
# https://github.com/geickelb/HSIP442_guest_lecture/blob/master/notebooks/modeling.ipynb
#
# scoring parameter for multi-classification: https://scikit-learn.org/stable/modules/model_evaluation.html#scoring-parameter (will try f1_samples and precision_samples and/or just accuracy)

# %% [markdown]
# **Define scoring function**

# %%
#scoring = ['AUC', 'Accuracy']

# %% [markdown]
# **Define Random Forest Hypertuning Function**

# %%
def hypertuning_fxn(X, y, nfolds, model , param_grid, scoring = 'roc_auc_ovo_weighted', verbose=True, cv = True, 
                    return_train_score = True): 
    """function that uses GridSearchCV to test a specified param_grid of hyperparameters and choose the optimal one based on nfolds cross-validation results. 

    Keyword arguments:
    model -- a 'fitted' sklearn model object 
    X -- predictor matrix (dtype='numpy array', required)
    y -- outcome vector (dtype='numpy array', required)
    cv -- if True, prints a the roc_auc score from 10-fold crossvalidation (dtype='boolean', default='True')
    """
    
    np.random.seed(12345)
    
    # The scorers can be either be one of the predefined metric strings or a scorer
    # callable, like the one returned by make_scorer
    #scoring = {'AUC': 'roc_auc_ovr', 'Accuracy': make_scorer(accuracy_score)}

    grid_search = GridSearchCV(estimator= model,
                                     param_grid=param_grid,
                                     cv=StratifiedKFold(nfolds), # stratified k-folds will preserve class balances - this function is what got the rest of the code to work with roc validation
                                     scoring=scoring,
                                     return_train_score=True,
                                     n_jobs = -1)
    
    #scoring = {'accuracy': 'accuracy', 'auc': 'roc_auc_ovr'}
    #scoring = {'AUC': 'roc_auc', 'Accuracy': make_scorer(accuracy_score)}
    
    #OneVsRestClassifier(grid_search.fit(X, y))   
    grid_search.fit(X, y)
    print(" scorer function: {}".format(scoring))
    print(" ##### CV performance: mean & sd scores #####")

    means = grid_search.cv_results_['mean_test_score']
    stds = grid_search.cv_results_['std_test_score']
    
    print('best cv score: {:0.3f}'.format(grid_search.best_score_))
    print('best cv params: ', grid_search.best_params_)

    worst_index=np.argmin(grid_search.cv_results_['mean_test_score'])
    print('worst cv score: {:0.3f}'.format(grid_search.cv_results_['mean_test_score'][worst_index]))
    print('worst cv params: ', grid_search.cv_results_['params'][worst_index])
    ##
    if verbose==True:
        for mean, std, params in zip(means, stds, grid_search.cv_results_['params']):
            print("%0.3f (+/-%0.03f) for %r"% (mean, std * 2, params))
    
    return(grid_search)
    #print(grid_search.cv_results_)

# %% [markdown]
# **Tune Hyperparameters**

# %%
### tuning RF hyperparameters
# Number of trees in random forest
n_estimators = [100, 300, 500, 1000] #  100, 300, 500, 1000
# Number of features to consider at every split
max_features = [3, 10, 'auto'] # 'auto' which is equivalent to sqrt(n_features)
# Maximum number of levels in tree
max_depth = [5, 8, 15, 25, 30]
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 5, 10, 15]

param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

model = RandomForestClassifier(criterion='entropy', random_state=12345)

rf_hyper=hypertuning_fxn(X_train, y_train, nfolds=10, model=model , param_grid=param_grid, scoring= 'roc_auc_ovo_weighted', cv = True, return_train_score = True)
# Out:
#  scorer function: roc_auc_ovo_weighted
#  ##### CV performance: mean & sd scores #####
# best cv score: 0.720
# best cv params:  {'max_depth': 8, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# worst cv score: 0.632
# worst cv params:  {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.632 (+/-0.173) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.664 (+/-0.211) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# 0.663 (+/-0.198) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# 0.660 (+/-0.204) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1000}
# 0.651 (+/-0.195) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# 0.676 (+/-0.201) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# 0.670 (+/-0.210) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
# 0.670 (+/-0.212) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1000}
# 0.656 (+/-0.159) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# 0.666 (+/-0.186) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# 0.667 (+/-0.198) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# 0.671 (+/-0.201) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 1000}
# 0.681 (+/-0.189) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 15, 'n_estimators': 100}
# 0.683 (+/-0.200) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 15, 'n_estimators': 300}
# 0.675 (+/-0.198) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 15, 'n_estimators': 500}
# 0.675 (+/-0.192) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 15, 'n_estimators': 1000}
# 0.652 (+/-0.141) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 100}
# 0.667 (+/-0.209) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 300}
# 0.663 (+/-0.212) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 500}
# 0.673 (+/-0.199) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 1000}
# 0.652 (+/-0.141) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 100}
# 0.667 (+/-0.209) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 300}
# 0.663 (+/-0.212) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 500}
# 0.673 (+/-0.199) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 1000}
# 0.652 (+/-0.141) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 100}
# 0.667 (+/-0.209) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 300}
# 0.663 (+/-0.212) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 500}
# 0.673 (+/-0.199) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 1000}
# 0.659 (+/-0.179) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 15, 'n_estimators': 100}
# 0.669 (+/-0.196) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 15, 'n_estimators': 300}
# 0.673 (+/-0.202) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 15, 'n_estimators': 500}
# 0.675 (+/-0.196) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 15, 'n_estimators': 1000}
# 0.664 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 300}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 500}
# 0.674 (+/-0.199) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 1000}
# 0.664 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 300}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 500}
# 0.674 (+/-0.199) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 1000}
# 0.664 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 300}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 500}
# 0.674 (+/-0.199) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 1000}
# 0.664 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 100}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 300}
# 0.675 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 500}
# 0.674 (+/-0.199) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 1000}
# 0.640 (+/-0.169) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 0.660 (+/-0.193) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 300}
# 0.671 (+/-0.194) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 500}
# 0.666 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 1000}
# 0.640 (+/-0.169) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 100}
# 0.660 (+/-0.193) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 300}
# 0.671 (+/-0.194) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 500}
# 0.666 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 1000}
# 0.640 (+/-0.169) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 100}
# 0.660 (+/-0.193) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 300}
# 0.671 (+/-0.194) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 500}
# 0.666 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 1000}
# 0.640 (+/-0.169) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 100}
# 0.660 (+/-0.193) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 300}
# 0.671 (+/-0.194) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 500}
# 0.666 (+/-0.197) for {'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 1000}
# 0.658 (+/-0.197) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.680 (+/-0.169) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
# 0.687 (+/-0.172) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 500}
# 0.679 (+/-0.185) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1000}
# 0.671 (+/-0.135) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}
# 0.687 (+/-0.154) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 300}
# 0.688 (+/-0.175) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 500}
# 0.679 (+/-0.172) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1000}
# 0.667 (+/-0.187) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 100}
# 0.677 (+/-0.176) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}
# 0.680 (+/-0.180) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 500}
# 0.672 (+/-0.194) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 1000}
# 0.664 (+/-0.192) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 15, 'n_estimators': 100}
# 0.668 (+/-0.209) for {'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 15, 'n_estimators': 300}
# 0
for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 100}
# 0.705 (+/-0.182) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 300}
# 0.705 (+/-0.177) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 500}
# 0.709 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 1000}
# 0.690 (+/-0.169) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 100}
# 0.705 (+/-0.182) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 300}
# 0.705 (+/-0.177) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 500}
# 0.709 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 1000}
# 0.690 (+/-0.169) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 100}
# 0.705 (+/-0.182) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 300}
# 0.705 (+/-0.177) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 500}
# 0.709 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 1000}
# 0.690 (+/-0.169) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 100}
# 0.705 (+/-0.182) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 300}
# 0.705 (+/-0.177) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 500}
# 0.709 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 10, 'min_samples_split': 15, 'n_estimators': 1000}
# 0.706 (+/-0.184) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 100}
# 0.712 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 300}
# 0.710 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 500}
# 0.711 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 2, 'n_estimators': 1000}
# 0.706 (+/-0.184) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 100}
# 0.712 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 300}
# 0.710 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 500}
# 0.711 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 5, 'n_estimators': 1000}
# 0.706 (+/-0.184) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 100}
# 0.712 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 300}
# 0.710 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 500}
# 0.711 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 10, 'n_estimators': 1000}
# 0.706 (+/-0.184) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 100}
# 0.712 (+/-0.192) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 300}
# 0.710 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 500}
# 0.711 (+/-0.195) for {'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 15, 'min_samples_split': 15, 'n_estimators': 1000}

# %% [markdown]
# **Return the Best Estimator**

# %%
print(rf_hyper.best_estimator_)
rf = rf_hyper.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=8, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=10,
#                        min_weight_fraction_leaf=0.0, n_estimators=500,
#                        n_jobs=None, oob_score=False, random_state=12345,
#                        verbose=0, warm_start=False)

# %% [markdown]
# # **Evaluate Model**

# %%
print(rf_hyper.classes_) # number of classes - this is an attribute of the rf classifier

# predict the probabilities of the classifier when applied to the test set - Note: [:,] shapes data into the right format for multiclass
rf_probs = rf_hyper.best_estimator_.predict_proba(X_test)[:,]
#rf_probs.shape
# Out:
# [0 1 2 3 4]

# %%
rf_preds = rf_hyper.best_estimator_.predict(X_test)[:,]
#rf_preds = rf_preds.reshape(-1,1).shape
#rf_preds

# %% [markdown]
# **Note:** ovr computes the AUC of each class against the rest [3] [4]. This treats the multiclass case in the same way as the multilabel case. Sensitive to class imbalance even when average == 'macro', because class imbalance affects the composition of each of the ‘rest’ groupings"
#
# Weighted: Calculate metrics for each label, and find their average, weighted by support (the number of true instances for each label).

# %%
#roc_auc_score(y_test, rf_probs, multi_class = 'ovr', average = 'weighted') # multi_class must be in ('ovo', 'ovr')

print('Roc_Auc_Score:')
roc_auc_score(y_test_multi, rf_probs, multi_class = 'ovo', average = 'weighted') # multi_class must be in ('ovo', 'ovr')#
# Out:
# Roc_Auc_Score:
# 0.7901200360553898

# %% [markdown]
# # **Confusion Matrix**

# %%
rf_preds = rf_hyper.best_estimator_.predict(X_test)[:,]
confusion_matrix(y_test, rf_preds)
# Out:
# array([[24,  0,  0,  1,  0],
#        [ 9,  6,  0,  3,  1],
#        [ 4,  1,  1,  2,  2],
#        [ 3,  4,  0, 14,  0],
#        [ 7,  4,  0,  0,  0]])

# %%
target_names = ['HEA', 'CRC', 'ESCA', 'HCC', 'STAD']
print(classification_report(y_test, rf_preds, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#          HEA       0.51      0.96      0.67        25
#          CRC       0.40      0.32      0.35        19
#         ESCA       1.00      0.10      0.18        10
#          HCC       0.70      0.67      0.68        21
#         STAD       0.00      0.00      0.00        11
#
#     accuracy                           0.52        86
#    macro avg       0.52      0.41      0.38        86
# weighted avg       0.52      0.52      0.46        86

# %% [markdown]
# # **Examine Important Features**
#
# Feature Importance for Multi-class classification:
# https://stackoverflow.com/questions/54562464/can-i-show-feature-importance-for-multioutputclassifier
#
# MultiOutputClassifier objects have an attribute called estimators_. If you run multi_forest.estimators_, you will get a list containing an object for each of your RandomForest classifiers.
#
# For each of these RandomForest classifier objects, you can access its feature importances through the feature_importances_ attribute.

# %%
# create empty list
feat_impts = [] 
# bind all rf estimators for each classifier (each multi-class output - in our case 7)
for clf in rf.estimators_:
    feat_impts.append(clf.feature_importances_)

# calculate the mean of features across genes
feat = np.mean(feat_impts, axis=0)
# create a list of features (gene names)
features = list(X_train_orig.columns.values) 
# add gene names to the means
feat_importances = pd.Series(feat, index=X_train_orig.columns)  

# plot feature importance for nlargest means 
feat_importances.nlargest(25).plot(kind='barh')
